# %%
import pandas as pd

train = pd.read_csv('task1_train.csv')
test = pd.read_csv('task1_test.csv')

# %%
import jieba
import numpy as np

train['sen_cut'] = train['joke'].apply(jieba.lcut)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\ADMINI~1\AppData\Local\Temp\jieba.cache
# Loading model cost 0.627 seconds.
# Prefix dict has been built succesfully.

# %%
X_train = train['sen_cut'].apply(lambda x: ' '.join(x)).tolist()
y_train = pd.get_dummies((np.asarray(train["label"])))
text = np.array(X_train)

# %%
from keras.preprocessing.text import Tokenizer
from keras_preprocessing.sequence import pad_sequences
import time

vocab_size = 30000
maxlen = 25

print("开始统计语料的词频信息...")
t = Tokenizer(vocab_size)
t.fit_on_texts(text)
word_index = t.word_index
print('完整的字典大小：', len(word_index))

print("开始序列化句子...")
X_train = t.texts_to_sequences(X_train)
print("开始对齐句子序列...")
X_train = pad_sequences(X_train, maxlen=maxlen, padding='post')
print("完成！")
# Out:
# Using TensorFlow backend.
# 开始统计语料的词频信息...
# 完整的字典大小： 29702
# 开始序列化句子...
# 开始对齐句子序列...
# 完成！

# %%
import copy

small_word_index = copy.deepcopy(word_index) # 防止原来的字典被改变
x = list(t.word_counts.items())
s = sorted(x, key=lambda p:p[1], reverse=True)
print("移除word_index字典中的低频词...")
for item in s[20000:]:
    small_word_index.pop(item[0]) # 对字典pop
print("完成！")
print(len(small_word_index))
print(len(word_index))
# Out:
# 移除word_index字典中的低频词...
# 完成！
# 20000
# 29702

# %%
print(type(X_train))
print(type(y_train))

print(X_train.shape)
print(y_train.shape)
# Out:
# <class 'numpy.ndarray'>
# <class 'pandas.core.frame.DataFrame'>
# (16420, 25)
# (16420, 2)

# %%
import gensim

model_file = 'E:/embedding/wiki.zh.vec' # input your file path
print("加载Word2Vec模型...")
wv_model = gensim.models.KeyedVectors.load_word2vec_format(model_file, binary=False)
# Out:
# 加载Word2Vec模型...

# %%
embedding_matrix = np.random.uniform(size=(vocab_size+1,300))
print("构建embedding_matrix...")
for word, index in small_word_index.items():
    try:
        word_vector = wv_model[word]
        embedding_matrix[index] = word_vector
    except:
        print("Word: [",word,"] not in wvmodel! Use random embedding instead.")
print("完成！")
print("Embedding matrix shape:\n",embedding_matrix.shape)
# Out:
# 构建embedding_matrix...
# Word: [ “ ] not in wvmodel! Use random embedding instead.
# Word: [ ” ] not in wvmodel! Use random embedding instead.
# Word: [ 两个 ] not in wvmodel! Use random embedding instead.
# Word: [ 地说 ] not in wvmodel! Use random embedding instead.
# Word: [ 这是 ] not in wvmodel! Use random embedding instead.
# Word: [ 每个 ] not in wvmodel! Use random embedding instead.
# Word: [ 我会 ] not in wvmodel! Use random embedding instead.
# Word: [ ’ ] not in wvmodel! Use random embedding instead.
# Word: [ 服务员 ] not in wvmodel! Use random embedding instead.
# Word: [ 有个 ] not in wvmodel! Use random embedding instead.
# Word: [ 哥们 ] not in wvmodel! Use random embedding instead.
# Word: [ 阿凡提 ] not in wvmodel! Use random embedding instead.
# Word: [ 5 ] not in wvmodel! Use random embedding instead.
# Word: [ 3 ] not in wvmodel! Use random embedding instead.
# Word: [ 10 ] not in wvmodel! Use random embedding instead.
# Word: [ 有没有 ] not in wvmodel! Use random embedding instead.
# Word: [ 三个 ] not in wvmodel! Use random embedding instead.
# Word: [ 看着 ] not in wvmodel! Use random embedding instead.
# Word: [ 答道 ] not in wvmodel! Use random embedding instead.
# Word: [ 2 ] not in wvmodel! Use random embedding instead.
# Word: [ 1 ] not in wvmodel! Use random embedding instead.
# Word: [ 嫁给 ] not in wvmodel! Use random embedding instead.
# Word: [ 是因为 ] not in wvmodel! Use random embedding instead.
# Word: [ 计算机 ] not in wvmodel! Use random embedding instead.
# Word: [ 20 ] not in wvmodel! Use random embedding instead.
# Word: [ 意味着 ] not in wvmodel! Use random embedding instead.
# Word: [ 大多数 ] not in wvmodel! Use random embedding instead.
# Word: [ 办公室 ] not in wvmodel! Use random embedding instead.
# Word: [ 50 ] not in wvmodel! Use random embedding instead.
# Word: [ 老妈 ] not in wvmodel! Use random embedding instead.
# Word: [ 4 ] not in wvmodel! Use random embedding instead.
# Word: [ 怎么办 ] not in wvmodel! Use random embedding instead.
# Word: [ 小时候 ] not in wvmodel! Use random embedding instead.
# Word: [ 还要 ] not in wvmodel! Use random embedding instead.
# Word: [ 地问 ] not in wvmodel! Use random embedding instead.
# Word: [ 第二天 ] not in wvmodel! Use random embedding instead.
# Word: [ 指着 ] not in wvmodel! Use random embedding instead.
# Word: [ 一会儿 ] not in wvmodel! Use random embedding instead.
# Word: [ 它会 ] not in wvmodel! Use random embedding instead.
# Word: [ 其他人 ] not in wvmodel! Use random embedding instead.
# Word: [ 一辆 ] not in wvmodel! Use random embedding instead.
# Word: [ 第一个 ] not in wvmodel! Use random embedding instead.
# Word: [ 怎么样 ] not in wvmodel! Use random embedding instead.
# Word: [ 年轻人 ] not in wvmodel! Use random embedding instead.
# Word: [ 8 ] not in wvmodel! Use random embedding instead.
# Word: [ 一会 ] not in wvmodel! Use random embedding instead.
# Word: [ 人会 ] not in wvmodel! Use random embedding instead.
# Word: [ 喊道 ] not in wvmodel! Use random embedding instead.
# Word: [ 自行车 ] not in wvmodel! Use random embedding instead.
# Word: [ 6 ] not in wvmodel! Use random embedding instead.
# Word: [ 7 ] not in wvmodel! Use random embedding instead.
# Word: [ 有钱 ] not in wvmodel! Use random embedding instead.
# Word: [ 同桌 ] not in wvmodel! Use random embedding instead.
# Word: [ 小女孩 ] not in wvmodel! Use random embedding instead.
# Word: [ 脸上 ] not in wvmodel! Use random embedding instead.
# Word: [ 看电视 ] not in wvmodel! Use random embedding instead.
# Word: [ 售货员 ] not in wvmodel! Use random embedding instead.
# Word: [ 动物园 ] not in wvmodel! Use random embedding instead.
# Word: [ 幼儿园 ] not in wvmodel! Use random embedding instead.
# Word: [ 小男孩 ] not in wvmodel! Use random embedding instead.
# Word: [ 四个 ] not in wvmodel! Use random embedding instead.
# Word: [ 小强 ] not in wvmodel! Use random embedding instead.
# Word: [ 两种 ] not in wvmodel! Use random embedding instead.
# Word: [ 干嘛 ] not in wvmodel! Use random embedding instead.
# Word: [ 100 ] not in wvmodel! Use random embedding instead.
# Word: [ 每当 ] not in wvmodel! Use random embedding instead.
# Word: [ 没事 ] not in wvmodel! Use random embedding instead.
# Word: [ 小张 ] not in wvmodel! Use random embedding instead.
# Word: [ 30 ] not in wvmodel! Use random embedding instead.
# Word: [ 嘴里 ] not in wvmodel! Use random embedding instead.
# Word: [ 墙上 ] not in wvmodel! Use random embedding instead.
# Word: [ 杰克 ] not in wvmodel! Use random embedding instead.
# Word: [ 你家 ] not in wvmodel! Use random embedding instead.
# Word: [ 只见 ] not in wvmodel! Use random embedding instead.
# Word: [ 9 ] not in wvmodel! Use random embedding instead.
# Word: [ 用来 ] not in wvmodel! Use random embedding instead.
# Word: [ 很难 ] not in wvmodel! Use random embedding instead.
# Word: [ 一场 ] not in wvmodel! Use random embedding instead.
# Word: [ 一顿 ] not in wvmodel! Use random embedding instead.
# Word: [ 头上 ] not in wvmodel! Use random embedding instead.
# Word: [ 是从 ] not in wvmodel! Use random embedding instead.
# Word: [ 小华 ] not in wvmodel! Use random embedding instead.
# Word: [ 所有人 ] not in wvmodel! Use random embedding instead.
# Word: [ 写道 ] not in wvmodel! Use random embedding instead.
# Word: [ 为啥 ] not in wvmodel! Use random embedding instead.
# Word: [ 两只 ] not in wvmodel! Use random embedding instead.
# Word: [ 什么样 ] not in wvmodel! Use random embedding instead.
# Word: [ 块钱 ] not in wvmodel! Use random embedding instead.
# Word: [ 只会 ] not in wvmodel! Use random embedding instead.
# Word: [ 中年 ] not in wvmodel! Use random embedding instead.
# Word: [ 他会 ] not in wvmodel! Use random embedding instead.
# Word: [ 工程师 ] not in wvmodel! Use random embedding instead.
# Word: [ 本书 ] not in wvmodel! Use random embedding instead.
# Word: [ 快点 ] not in wvmodel! Use random embedding instead.
# Word: [ 停下来 ] not in wvmodel! Use random embedding instead.
# Word: [ 电视机 ] not in wvmodel! Use random embedding instead.
# Word: [ 90 ] not in wvmodel! Use random embedding instead.
# Word: [ 40 ] not in wvmodel! Use random embedding instead.
# Word: [ 圣诞节 ] not in wvmodel! Use random embedding instead.
# Word: [ 12 ] not in wvmodel! Use random embedding instead.
# Word: [ 一段时间 ] not in wvmodel! Use random embedding instead.
# Word: [ 干吗 ] not in wvmodel! Use random embedding instead.
# Word: [ 18 ] not in wvmodel! Use random embedding instead.
# Word: [ 聪明人 ] not in wvmodel! Use random embedding instead.
# Word: [ 一个月 ] not in wvmodel! Use random embedding instead.
# Word: [ 有时候 ] not in wvmodel! Use random embedding instead.
# Word: [ 60 ] not in wvmodel! Use random embedding instead.
# Word: [ 怎么回事 ] not in wvmodel! Use random embedding instead.
# Word: [ 一小 ] not in wvmodel! Use random embedding instead.
# Word: [ 不让 ] not in wvmodel! Use random embedding instead.
# Word: [ 公交车 ] not in wvmodel! Use random embedding instead.
# Word: [ 女同学 ] not in wvmodel! Use random embedding instead.
# Word: [ 这句 ] not in wvmodel! Use random embedding instead.
# Word: [ 试试 ] not in wvmodel! Use random embedding instead.
# Word: [ 一瓶 ] not in wvmodel! Use random embedding instead.
# Word: [ 小红 ] not in wvmodel! Use random embedding instead.
# Word: [ 推销员 ] not in wvmodel! Use random embedding instead.
# Word: [ 我用 ] not in wvmodel! Use random embedding instead.
# Word: [ 图书馆 ] not in wvmodel! Use random embedding instead.
# Word: [ 举手 ] not in wvmodel! Use random embedding instead.
# Word: [ 看过 ] not in wvmodel! Use random embedding instead.
# Word: [ 圣诞老人 ] not in wvmodel! Use random embedding instead.
# Word: [ 24 ] not in wvmodel! Use random embedding instead.
# Word: [ 实际上 ] not in wvmodel! Use random embedding instead.
# Word: [ 两人 ] not in wvmodel! Use random embedding instead.
# Word: [ 这件 ] not in wvmodel! Use random embedding instead.
# Word: [ 没见 ] not in wvmodel! Use random embedding instead.
# Word: [ 睡不着 ] not in wvmodel! Use random embedding instead.
# Word: [ 哥们儿 ] not in wvmodel! Use random embedding instead.
# Word: [ 明说 ] not in wvmodel! Use random embedding instead.
# Word: [ 很棒 ] not in wvmodel! Use random embedding instead.
# Word: [ 女同事 ] not in wvmodel! Use random embedding instead.
# Word: [ 身后 ] not in wvmodel! Use random embedding instead.
# Word: [ 一脸 ] not in wvmodel! Use random embedding instead.
# Word: [ 0 ] not in wvmodel! Use random embedding instead.
# Word: [ 理发师 ] not in wvmodel! Use random embedding instead.
# Word: [ 语文课 ] not in wvmodel! Use random embedding instead.
# Word: [ 说完 ] not in wvmodel! Use random embedding instead.
# Word: [ 科学家 ] not in wvmodel! Use random embedding instead.
# Word: [ 发现自己 ] not in wvmodel! Use random embedding instead.
# Word: [ 程序员 ] not in wvmodel! Use random embedding instead.
# Word: [ 鼠标 ] not in wvmodel! Use random embedding instead.
# Word: [ 没人 ] not in wvmodel! Use random embedding instead.
# Word: [ 就让 ] not in wvmodel! Use random embedding instead.
# Word: [ 15 ] not in wvmodel! Use random embedding instead.
# Word: [ 很穷 ] not in wvmodel! Use random embedding instead.
# Word: [ 小儿子 ] not in wvmodel! Use random embedding instead.
# Word: [ 就行了 ] not in wvmodel! Use random embedding instead.
# Word: [ 长时间 ] not in wvmodel! Use random embedding instead.
# Word: [ 树上 ] not in wvmodel! Use random embedding instead.
# Word: [ 我怕 ] not in wvmodel! Use random embedding instead.
# Word: [ 五个 ] not in wvmodel! Use random embedding instead.
# Word: [ 爸妈 ] not in wvmodel! Use random embedding instead.
# Word: [ 运动员 ] not in wvmodel! Use random embedding instead.
# Word: [ 掉下来 ] not in wvmodel! Use random embedding instead.
# Word: [ 淡定 ] not in wvmodel! Use random embedding instead.
# Word: [ 某女 ] not in wvmodel! Use random embedding instead.
# Word: [ 三岁 ] not in wvmodel! Use random embedding instead.
# Word: [ 悲观主义 ] not in wvmodel! Use random embedding instead.
# Word: [ 爱迪生 ] not in wvmodel! Use random embedding instead.
# Word: [ 爸爸妈妈 ] not in wvmodel! Use random embedding instead.
# Word: [ 200 ] not in wvmodel! Use random embedding instead.
# Word: [ 所说 ] not in wvmodel! Use random embedding instead.
# Word: [ 情人节 ] not in wvmodel! Use random embedding instead.
# Word: [ 出错 ] not in wvmodel! Use random embedding instead.
# Word: [ 王老汉 ] not in wvmodel! Use random embedding instead.
# Word: [ 营业员 ] not in wvmodel! Use random embedding instead.
# Word: [ 还会 ] not in wvmodel! Use random embedding instead.
# Word: [ 很漂亮 ] not in wvmodel! Use random embedding instead.
# Word: [ 单身汉 ] not in wvmodel! Use random embedding instead.
# Word: [ 取决于 ] not in wvmodel! Use random embedding instead.
# Word: [ 闻到 ] not in wvmodel! Use random embedding instead.
# Word: [ 班里 ] not in wvmodel! Use random embedding instead.
# Word: [ 火车站 ] not in wvmodel! Use random embedding instead.
# Word: [ 服务生 ] not in wvmodel! Use random embedding instead.
# Word: [ 拨打 ] not in wvmodel! Use random embedding instead.
# Word: [ 小鸟 ] not in wvmodel! Use random embedding instead.
# Word: [ 这辈子 ] not in wvmodel! Use random embedding instead.
# Word: [ 我刚 ] not in wvmodel! Use random embedding instead.
# Word: [ 接过 ] not in wvmodel! Use random embedding instead.
# Word: [ 听后 ] not in wvmodel! Use random embedding instead.
# Word: [ 一分钟 ] not in wvmodel! Use random embedding instead.
# Word: [ 半个 ] not in wvmodel! Use random embedding instead.
# Word: [ 怎样才能 ] not in wvmodel! Use random embedding instead.
# Word: [ 答到 ] not in wvmodel! Use random embedding instead.
# Word: [ 克林顿 ] not in wvmodel! Use random embedding instead.
# Word: [ 问问 ] not in wvmodel! Use random embedding instead.
# Word: [ 同一个 ] not in wvmodel! Use random embedding instead.
# Word: [ 谈恋爱 ] not in wvmodel! Use random embedding instead.
# Word: [ 结账 ] not in wvmodel! Use random embedding instead.
# Word: [ 刹车 ] not in wvmodel! Use random embedding instead.
# Word: [ 电子邮件 ] not in wvmodel! Use random embedding instead.
# Word: [ 出租车 ] not in wvmodel! Use random embedding instead.
# Word: [ 六个 ] not in wvmodel! Use random embedding instead.
# Word: [ 人民币 ] not in wvmodel! Use random embedding instead.
# Word: [ 11 ] not in wvmodel! Use random embedding instead.
# Word: [ 问小明 ] not in wvmodel! Use random embedding instead.
# Word: [ 有次 ] not in wvmodel! Use random embedding instead.
# Word: [ 500 ] not in wvmodel! Use random embedding instead.
# Word: [ 闭嘴 ] not in wvmodel! Use random embedding instead.
# Word: [ 语重心长 ] not in wvmodel! Use random embedding instead.
# Word: [ 称之为 ] not in wvmodel! Use random embedding instead.
# Word: [ 80 ] not in wvmodel! Use random embedding instead.
# Word: [ 卫生纸 ] not in wvmodel! Use random embedding instead.
# Word: [ 想着 ] not in wvmodel! Use random embedding instead.
# Word: [ 两天 ] not in wvmodel! Use random embedding instead.
# Word: [ 买不到 ] not in wvmodel! Use random embedding instead.
# Word: [ 发短信 ] not in wvmodel! Use random embedding instead.
# Word: [ 课上 ] not in wvmodel! Use random embedding instead.
# Word: [ 河里 ] not in wvmodel! Use random embedding instead.
# Word: [ 有天 ] not in wvmodel! Use random embedding instead.
# Word: [ 时会 ] not in wvmodel! Use random embedding instead.
# Word: [ 解决方案 ] not in wvmodel! Use random embedding instead.
# Word: [ 满脸 ] not in wvmodel! Use random embedding instead.
# Word: [ 总有 ] not in wvmodel! Use random embedding instead.
# Word: [ 某个 ] not in wvmodel! Use random embedding instead.
# Word: [ 越少 ] not in wvmodel! Use random embedding instead.
# Word: [ 小刚 ] not in wvmodel! Use random embedding instead.
# Word: [ 从来不 ] not in wvmodel! Use random embedding instead.
# Word: [ 变老 ] not in wvmodel! Use random embedding instead.
# Word: [ 车上 ] not in wvmodel! Use random embedding instead.
# Word: [ 21 ] not in wvmodel! Use random embedding instead.
# Word: [ 更糟 ] not in wvmodel! Use random embedding instead.
# Word: [ 递给 ] not in wvmodel! Use random embedding instead.
# Word: [ 成正比 ] not in wvmodel! Use random embedding instead.
# Word: [ 二货 ] not in wvmodel! Use random embedding instead.
# Word: [ 摇头 ] not in wvmodel! Use random embedding instead.
# Word: [ 一点点 ] not in wvmodel! Use random embedding instead.
# Word: [ 披萨 ] not in wvmodel! Use random embedding instead.
# Word: [ 70 ] not in wvmodel! Use random embedding instead.
# Word: [ 不料 ] not in wvmodel! Use random embedding instead.
# Word: [ 统计数据 ] not in wvmodel! Use random embedding instead.
# Word: [ 不仅仅 ] not in wvmodel! Use random embedding instead.
# Word: [ 不要脸 ] not in wvmodel! Use random embedding instead.
# Word: [ 咱俩 ] not in wvmodel! Use random embedding instead.
# Word: [ 一切都是 ] not in wvmodel! Use random embedding instead.
# Word: [ 说实话 ] not in wvmodel! Use random embedding instead.
# Word: [ 另一只 ] not in wvmodel! Use random embedding instead.
# Word: [ 一口气 ] not in wvmodel! Use random embedding instead.
# Word: [ 数学老师 ] not in wvmodel! Use random embedding instead.
# Word: [ 大吼 ] not in wvmodel! Use random embedding instead.
# Word: [ 打麻将 ] not in wvmodel! Use random embedding instead.
# Word: [ 爱是 ] not in wvmodel! Use random embedding instead.
# Word: [ 生个 ] not in wvmodel! Use random embedding instead.
# Word: [ 好好学习 ] not in wvmodel! Use random embedding instead.
# Word: [ 卫生间 ] not in wvmodel! Use random embedding instead.
# Word: [ 哲学家 ] not in wvmodel! Use random embedding instead.
# Word: [ 洗衣机 ] not in wvmodel! Use random embedding instead.
# Word: [ 说好 ] not in wvmodel! Use random embedding instead.
# Word: [ 奶酪 ] not in wvmodel! Use random embedding instead.
# Word: [ 想过 ] not in wvmodel! Use random embedding instead.
# Word: [ 要死 ] not in wvmodel! Use random embedding instead.
# Word: [ 99 ] not in wvmodel! Use random embedding instead.
# Word: [ 飞行员 ] not in wvmodel! Use random embedding instead.
# Word: [ 做些 ] not in wvmodel! Use random embedding instead.
# Word: [ 公共汽车 ] not in wvmodel! Use random embedding instead.
# Word: [ 舍友 ] not in wvmodel! Use random embedding instead.
# Word: [ 越来越少 ] not in wvmodel! Use random embedding instead.
# Word: [ 转过 ] not in wvmodel! Use random embedding instead.
# Word: [ 秃顶 ] not in wvmodel! Use random embedding instead.
# Word: [ 两名 ] not in wvmodel! Use random embedding instead.
# Word: [ 问一 ] not in wvmodel! Use random embedding instead.
# Word: [ 发了 ] not in wvmodel! Use random embedding instead.
# Word: [ 天气预报 ] not in wvmodel! Use random embedding instead.
# Word: [ 无论如何 ] not in wvmodel! Use random embedding instead.
# Word: [ 第一句 ] not in wvmodel! Use random embedding instead.
# Word: [ 下联 ] not in wvmodel! Use random embedding instead.
# Word: [ 不要紧 ] not in wvmodel! Use random embedding instead.
# Word: [ 男同学 ] not in wvmodel! Use random embedding instead.
# Word: [ 一个男孩 ] not in wvmodel! Use random embedding instead.
# Word: [ 这话 ] not in wvmodel! Use random embedding instead.
# Word: [ 成绩单 ] not in wvmodel! Use random embedding instead.
# Word: [ 被窝 ] not in wvmodel! Use random embedding instead.
# Word: [ 忘带 ] not in wvmodel! Use random embedding instead.
# Word: [ 不甜 ] not in wvmodel! Use random embedding instead.
# Word: [ 进门 ] not in wvmodel! Use random embedding instead.
# Word: [ 保险杠 ] not in wvmodel! Use random embedding instead.
# Word: [ 一棵树 ] not in wvmodel! Use random embedding instead.
# Word: [ 车里 ] not in wvmodel! Use random embedding instead.
# Word: [ 那条 ] not in wvmodel! Use random embedding instead.
# Word: [ 鸟儿 ] not in wvmodel! Use random embedding instead.
# Word: [ 想一想 ] not in wvmodel! Use random embedding instead.
# Word: [ 1000 ] not in wvmodel! Use random embedding instead.
# Word: [ 多人 ] not in wvmodel! Use random embedding instead.
# Word: [ 却是 ] not in wvmodel! Use random embedding instead.
# Word: [ 这辆 ] not in wvmodel! Use random embedding instead.
# Word: [ 我该 ] not in wvmodel! Use random embedding instead.
# Word: [ 一本正经 ] not in wvmodel! Use random embedding instead.
# Word: [ 小女儿 ] not in wvmodel! Use random embedding instead.
# Word: [ 结了婚 ] not in wvmodel! Use random embedding instead.
# Word: [ 吃完饭 ] not in wvmodel! Use random embedding instead.
# Word: [ 弄清楚 ] not in wvmodel! Use random embedding instead.
# Word: [ 说些 ] not in wvmodel! Use random embedding instead.
# Word: [ 买不起 ] not in wvmodel! Use random embedding instead.
# Word: [ 完后 ] not in wvmodel! Use random embedding instead.
# Word: [ 我生 ] not in wvmodel! Use random embedding instead.
# Word: [ 忍无可忍 ] not in wvmodel! Use random embedding instead.
# Word: [ 管理员 ] not in wvmodel! Use random embedding instead.
# Word: [ 接电话 ] not in wvmodel! Use random embedding instead.
# Word: [ 降落伞 ] not in wvmodel! Use random embedding instead.
# Word: [ 响起 ] not in wvmodel! Use random embedding instead.
# Word: [ 脱口而出 ] not in wvmodel! Use random embedding instead.
# Word: [ 俱乐部 ] not in wvmodel! Use random embedding instead.
# Word: [ 神经病 ] not in wvmodel! Use random embedding instead.
# Word: [ 一笔 ] not in wvmodel! Use random embedding instead.
# Word: [ 领导者 ] not in wvmodel! Use random embedding instead.
# Word: [ 第一天 ] not in wvmodel! Use random embedding instead.
# Word: [ 你别 ] not in wvmodel! Use random embedding instead.
# Word: [ 两件事 ] not in wvmodel! Use random embedding instead.
# Word: [ 两位 ] not in wvmodel! Use random embedding instead.
# Word: [ 问其 ] not in wvmodel! Use random embedding instead.
# Word: [ 却说 ] not in wvmodel! Use random embedding instead.
# Word: [ 委员会 ] not in wvmodel! Use random embedding instead.
# Word: [ 纪念日 ] not in wvmodel! Use random embedding instead.
# Word: [ 爱我吗 ] not in wvmodel! Use random embedding instead.
# Word: [ 一模一样 ] not in wvmodel! Use random embedding instead.
# Word: [ 一则 ] not in wvmodel! Use random embedding instead.
# Word: [ 立马 ] not in wvmodel! Use random embedding instead.
# Word: [ 会上 ] not in wvmodel! Use random embedding instead.
# Word: [ 边上 ] not in wvmodel! Use random embedding instead.
# Word: [ 马戏团 ] not in wvmodel! Use random embedding instead.
# Word: [ 安眠药 ] not in wvmodel! Use random embedding instead.
# Word: [ 人有 ] not in wvmodel! Use random embedding instead.
# Word: [ 那人 ] not in wvmodel! Use random embedding instead.
# Word: [ 陷入困境 ] not in wvmodel! Use random embedding instead.
# Word: [ 眼里 ] not in wvmodel! Use random embedding instead.
# Word: [ 点名 ] not in wvmodel! Use random embedding instead.
# Word: [ 学到 ] not in wvmodel! Use random embedding instead.
# Word: [ 关上 ] not in wvmodel! Use random embedding instead.
# Word: [ 生物课 ] not in wvmodel! Use random embedding instead.
# Word: [ 这有 ] not in wvmodel! Use random embedding instead.
# Word: [ 奥运会 ] not in wvmodel! Use random embedding instead.
# Word: [ 这年头 ] not in wvmodel! Use random embedding instead.
# Word: [ 西游记 ] not in wvmodel! Use random embedding instead.
# Word: [ 谁知 ] not in wvmodel! Use random embedding instead.
# Word: [ 那好 ] not in wvmodel! Use random embedding instead.
# Word: [ 清明节 ] not in wvmodel! Use random embedding instead.
# Word: [ 音乐家 ] not in wvmodel! Use random embedding instead.
# Word: [ 爱好者 ] not in wvmodel! Use random embedding instead.
# Word: [ 这家 ] not in wvmodel! Use random embedding instead.
# Word: [ 三件 ] not in wvmodel! Use random embedding instead.
# Word: [ 两年 ] not in wvmodel! Use random embedding instead.
# Word: [ 打呼噜 ] not in wvmodel! Use random embedding instead.
# Word: [ 人来 ] not in wvmodel! Use random embedding instead.
# Word: [ 归咎于 ] not in wvmodel! Use random embedding instead.
# Word: [ 主义者 ] not in wvmodel! Use random embedding instead.
# Word: [ 领着 ] not in wvmodel! Use random embedding instead.
# Word: [ 去过 ] not in wvmodel! Use random embedding instead.
# Word: [ 对此 ] not in wvmodel! Use random embedding instead.
# Word: [ 男同事 ] not in wvmodel! Use random embedding instead.
# Word: [ 跳楼 ] not in wvmodel! Use random embedding instead.
# Word: [ 35 ] not in wvmodel! Use random embedding instead.
# Word: [ 英语老师 ] not in wvmodel! Use random embedding instead.
# Word: [ 阿花 ] not in wvmodel! Use random embedding instead.
# Word: [ 哈哈哈 ] not in wvmodel! Use random embedding instead.
# Word: [ 吸取教训 ] not in wvmodel! Use random embedding instead.
# Word: [ 讲卫生 ] not in wvmodel! Use random embedding instead.
# Word: [ 犯错误 ] not in wvmodel! Use random embedding instead.
# Word: [ 公务员 ] not in wvmodel! Use random embedding instead.
# Word: [ 上联 ] not in wvmodel! Use random embedding instead.
# Word: [ 顶部 ] not in wvmodel! Use random embedding instead.
# Word: [ 16 ] not in wvmodel! Use random embedding instead.
# Word: [ 我考 ] not in wvmodel! Use random embedding instead.
# Word: [ 实验室 ] not in wvmodel! Use random embedding instead.
# Word: [ 自我介绍 ] not in wvmodel! Use random embedding instead.
# Word: [ 两岁 ] not in wvmodel! Use random embedding instead.
# Word: [ 几分钟 ] not in wvmodel! Use random embedding instead.
# Word: [ 2000 ] not in wvmodel! Use random embedding instead.
# Word: [ 张开嘴 ] not in wvmodel! Use random embedding instead.
# Word: [ 憋不住 ] not in wvmodel! Use random embedding instead.
# Word: [ 一年级 ] not in wvmodel! Use random embedding instead.
# Word: [ 买点 ] not in wvmodel! Use random embedding instead.
# Word: [ 比尔 ] not in wvmodel! Use random embedding instead.
# Word: [ 贱人 ] not in wvmodel! Use random embedding instead.
# Word: [ 多长时间 ] not in wvmodel! Use random embedding instead.
# Word: [ 要钱 ] not in wvmodel! Use random embedding instead.
# Word: [ 乐观主义 ] not in wvmodel! Use random embedding instead.
# Word: [ 告诉您 ] not in wvmodel! Use random embedding instead.
# Word: [ 约翰尼 ] not in wvmodel! Use random embedding instead.
# Word: [ 喜剧演员 ] not in wvmodel! Use random embedding instead.
# Word: [ 洗脸 ] not in wvmodel! Use random embedding instead.
# Word: [ 戴眼镜 ] not in wvmodel! Use random embedding instead.
# Word: [ 进水 ] not in wvmodel! Use random embedding instead.
# Word: [ 画画 ] not in wvmodel! Use random embedding instead.
# Word: [ 毫不犹豫 ] not in wvmodel! Use random embedding instead.
# Word: [ 小胖 ] not in wvmodel! Use random embedding instead.
# Word: [ 低声 ] not in wvmodel! Use random embedding instead.
# Word: [ 数学课 ] not in wvmodel! Use random embedding instead.
# Word: [ 事实上 ] not in wvmodel! Use random embedding instead.
# Word: [ 办事员 ] not in wvmodel! Use random embedding instead.
# Word: [ 卖掉 ] not in wvmodel! Use random embedding instead.
# Word: [ 这条 ] not in wvmodel! Use random embedding instead.
# Word: [ 禽兽 ] not in wvmodel! Use random embedding instead.
# Word: [ 老李 ] not in wvmodel! Use random embedding instead.
# Word: [ 不听话 ] not in wvmodel! Use random embedding instead.
# Word: [ 围着 ] not in wvmodel! Use random embedding instead.
# Word: [ 很长 ] not in wvmodel! Use random embedding instead.
# Word: [ 无神论者 ] not in wvmodel! Use random embedding instead.
# Word: [ 高尔夫球 ] not in wvmodel! Use random embedding instead.
# Word: [ 两条 ] not in wvmodel! Use random embedding instead.
# Word: [ 店里 ] not in wvmodel! Use random embedding instead.
# Word: [ 老总 ] not in wvmodel! Use random embedding instead.
# Word: [ 假钞 ] not in wvmodel! Use random embedding instead.
# Word: [ 请原谅 ] not in wvmodel! Use random embedding instead.
# Word: [ 三种 ] not in wvmodel! Use random embedding instead.
# Word: [ 国税局 ] not in wvmodel! Use random embedding instead.
# Word: [ 泪流满面 ] not in wvmodel! Use random embedding instead.
# Word: [ 没钱 ] not in wvmodel! Use random embedding instead.
# Word: [ 肯德基 ] not in wvmodel! Use random embedding instead.
# Word: [ 小妹妹 ] not in wvmodel! Use random embedding instead.
# Word: [ 朋友家 ] not in wvmodel! Use random embedding instead.
# Word: [ 某大学 ] not in wvmodel! Use random embedding instead.
# Word: [ 这张 ] not in wvmodel! Use random embedding instead.
# Word: [ 脑细胞 ] not in wvmodel! Use random embedding instead.
# Word: [ 要说 ] not in wvmodel! Use random embedding instead.
# Word: [ 在生活中 ] not in wvmodel! Use random embedding instead.
# Word: [ t恤 ] not in wvmodel! Use random embedding instead.
# Word: [ 喝咖啡 ] not in wvmodel! Use random embedding instead.
# Word: [ 这天 ] not in wvmodel! Use random embedding instead.
# Word: [ 时说 ] not in wvmodel! Use random embedding instead.
# Word: [ 我答 ] not in wvmodel! Use random embedding instead.
# Word: [ 不爱 ] not in wvmodel! Use random embedding instead.
# Word: [ 这份 ] not in wvmodel! Use random embedding instead.
# Word: [ 走来 ] not in wvmodel! Use random embedding instead.
# Word: [ 取名 ] not in wvmodel! Use random embedding instead.
# Word: [ 用手 ] not in wvmodel! Use random embedding instead.
# Word: [ 外科医生 ] not in wvmodel! Use random embedding instead.
# Word: [ 时侯 ] not in wvmodel! Use random embedding instead.
# Word: [ 卫生巾 ] not in wvmodel! Use random embedding instead.
# Word: [ 另一半 ] not in wvmodel! Use random embedding instead.
# Word: [ 数学家 ] not in wvmodel! Use random embedding instead.
# Word: [ 世界地图 ] not in wvmodel! Use random embedding instead.
# Word: [ 小丽 ] not in wvmodel! Use random embedding instead.
# Word: [ 城里 ] not in wvmodel! Use random embedding instead.
# Word: [ 做点 ] not in wvmodel! Use random embedding instead.
# Word: [ 小家伙 ] not in wvmodel! Use random embedding instead.
# Word: [ 母猪 ] not in wvmodel! Use random embedding instead.
# Word: [ 枪杀 ] not in wvmodel! Use random embedding instead.
# Word: [ 前天 ] not in wvmodel! Use random embedding instead.
# Word: [ 电话号码 ] not in wvmodel! Use random embedding instead.
# Word: [ 微信 ] not in wvmodel! Use random embedding instead.
# Word: [ 安全带 ] not in wvmodel! Use random embedding instead.
# Word: [ 在线 ] not in wvmodel! Use random embedding instead.
# Word: [ 那家伙 ] not in wvmodel! Use random embedding instead.
# Word: [ 贴纸 ] not in wvmodel! Use random embedding instead.
# Word: [ 事是 ] not in wvmodel! Use random embedding instead.
# Word: [ 刚出生 ] not in wvmodel! Use random embedding instead.
# Word: [ 32 ] not in wvmodel! Use random embedding instead.
# Word: [ 亲嘴 ] not in wvmodel! Use random embedding instead.
# Word: [ 马路上 ] not in wvmodel! Use random embedding instead.
# Word: [ 切勿 ] not in wvmodel! Use random embedding instead.
# Word: [ 借钱 ] not in wvmodel! Use random embedding instead.
# Word: [ 一见 ] not in wvmodel! Use random embedding instead.
# Word: [ 罚单 ] not in wvmodel! Use random embedding instead.
# Word: [ 建筑物 ] not in wvmodel! Use random embedding instead.
# Word: [ 毫无意义 ] not in wvmodel! Use random embedding instead.
# Word: [ 河边 ] not in wvmodel! Use random embedding instead.
# Word: [ 同性恋 ] not in wvmodel! Use random embedding instead.
# Word: [ 二是 ] not in wvmodel! Use random embedding instead.
# Word: [ 制造商 ] not in wvmodel! Use random embedding instead.
# Word: [ 不起作用 ] not in wvmodel! Use random embedding instead.
# Word: [ 老鼠药 ] not in wvmodel! Use random embedding instead.
# Word: [ 运动会 ] not in wvmodel! Use random embedding instead.
# Word: [ 面试官 ] not in wvmodel! Use random embedding instead.
# Word: [ 一词 ] not in wvmodel! Use random embedding instead.
# Word: [ 美分 ] not in wvmodel! Use random embedding instead.
# Word: [ 千万别 ] not in wvmodel! Use random embedding instead.
# Word: [ 记忆力 ] not in wvmodel! Use random embedding instead.
# Word: [ 十个 ] not in wvmodel! Use random embedding instead.
# Word: [ 好极了 ] not in wvmodel! Use random embedding instead.
# Word: [ 出去玩 ] not in wvmodel! Use random embedding instead.
# Word: [ 阅读障碍 ] not in wvmodel! Use random embedding instead.
# Word: [ 隐身 ] not in wvmodel! Use random embedding instead.
# Word: [ 更长 ] not in wvmodel! Use random embedding instead.
# Word: [ 网民 ] not in wvmodel! Use random embedding instead.
# Word: [ 上班时间 ] not in wvmodel! Use random embedding instead.
# Word: [ 工作人员 ] not in wvmodel! Use random embedding instead.
# Word: [ 方便面 ] not in wvmodel! Use random embedding instead.
# Word: [ 网吧 ] not in wvmodel! Use random embedding instead.
# Word: [ 老农 ] not in wvmodel! Use random embedding instead.
# Word: [ 写信给 ] not in wvmodel! Use random embedding instead.
# Word: [ 闲聊 ] not in wvmodel! Use random embedding instead.
# Word: [ 小孩儿 ] not in wvmodel! Use random embedding instead.
# Word: [ 页面 ] not in wvmodel! Use random embedding instead.
# Word: [ 换成 ] not in wvmodel! Use random embedding instead.
# Word: [ 从没 ] not in wvmodel! Use random embedding instead.
# Word: [ 小名 ] not in wvmodel! Use random embedding instead.
# Word: [ 横批 ] not in wvmodel! Use random embedding instead.
# Word: [ 45 ] not in wvmodel! Use random embedding instead.
# Word: [ 外国人 ] not in wvmodel! Use random embedding instead.
# Word: [ 宝马 ] not in wvmodel! Use random embedding instead.
# Word: [ 师兄 ] not in wvmodel! Use random embedding instead.
# Word: [ 老大爷 ] not in wvmodel! Use random embedding instead.
# Word: [ 考上 ] not in wvmodel! Use random embedding instead.
# Word: [ 怒气冲冲 ] not in wvmodel! Use random embedding instead.
# Word: [ 北极熊 ] not in wvmodel! Use random embedding instead.
# Word: [ 5000 ] not in wvmodel! Use random embedding instead.
# Word: [ 我俩 ] not in wvmodel! Use random embedding instead.
# Word: [ 大惊 ] not in wvmodel! Use random embedding instead.
# Word: [ 打了个 ] not in wvmodel! Use random embedding instead.
# Word: [ 这道题 ] not in wvmodel! Use random embedding instead.
# Word: [ 第一名 ] not in wvmodel! Use random embedding instead.
# Word: [ 摩托车 ] not in wvmodel! Use random embedding instead.
# Word: [ 张嘴 ] not in wvmodel! Use random embedding instead.
# Word: [ 婊子 ] not in wvmodel! Use random embedding instead.
# Word: [ 互联网 ] not in wvmodel! Use random embedding instead.
# Word: [ 电影院 ] not in wvmodel! Use random embedding instead.
# Word: [ 我敢 ] not in wvmodel! Use random embedding instead.
# Word: [ 救护车 ] not in wvmodel! Use random embedding instead.
# Word: [ 挡风玻璃 ] not in wvmodel! Use random embedding instead.
# Word: [ 300 ] not in wvmodel! Use random embedding instead.
# Word: [ 一家人 ] not in wvmodel! Use random embedding instead.
# Word: [ 新买 ] not in wvmodel! Use random embedding instead.
# Word: [ 法国人 ] not in wvmodel! Use random embedding instead.
# Word: [ 被困 ] not in wvmodel! Use random embedding instead.
# Word: [ 2b ] not in wvmodel! Use random embedding instead.
# Word: [ 防盗门 ] not in wvmodel! Use random embedding instead.
# Word: [ 三明治 ] not in wvmodel! Use random embedding instead.
# Word: [ 某君 ] not in wvmodel! Use random embedding instead.
# Word: [ 猪八戒 ] not in wvmodel! Use random embedding instead.
# Word: [ 爱尔兰人 ] not in wvmodel! Use random embedding instead.
# Word: [ 更难 ] not in wvmodel! Use random embedding instead.
# Word: [ 吃药 ] not in wvmodel! Use random embedding instead.
# Word: [ 给定 ] not in wvmodel! Use random embedding instead.
# Word: [ 吃饱 ] not in wvmodel! Use random embedding instead.
# Word: [ 无法忍受 ] not in wvmodel! Use random embedding instead.
# Word: [ 太久 ] not in wvmodel! Use random embedding instead.
# Word: [ 我姐 ] not in wvmodel! Use random embedding instead.
# Word: [ 期末考试 ] not in wvmodel! Use random embedding instead.
# Word: [ 本事 ] not in wvmodel! Use random embedding instead.
# Word: [ 一盘 ] not in wvmodel! Use random embedding instead.
# Word: [ 办公桌 ] not in wvmodel! Use random embedding instead.
# Word: [ 机械师 ] not in wvmodel! Use random embedding instead.
# Word: [ 那女 ] not in wvmodel! Use random embedding instead.
# Word: [ 两边 ] not in wvmodel! Use random embedding instead.
# Word: [ 车子 ] not in wvmodel! Use random embedding instead.
# Word: [ 无论是 ] not in wvmodel! Use random embedding instead.
# Word: [ 喝啤酒 ] not in wvmodel! Use random embedding instead.
# Word: [ 000 ] not in wvmodel! Use random embedding instead.
# Word: [ 的哥 ] not in wvmodel! Use random embedding instead.
# Word: [ 买个 ] not in wvmodel! Use random embedding instead.
# Word: [ 讲完 ] not in wvmodel! Use random embedding instead.
# Word: [ 难听 ] not in wvmodel! Use random embedding instead.
# Word: [ 到时候 ] not in wvmodel! Use random embedding instead.
# Word: [ 太难 ] not in wvmodel! Use random embedding instead.
# Word: [ 机器人 ] not in wvmodel! Use random embedding instead.
# Word: [ 一整天 ] not in wvmodel! Use random embedding instead.
# Word: [ 多钱 ] not in wvmodel! Use random embedding instead.
# Word: [ 旁观者 ] not in wvmodel! Use random embedding instead.
# Word: [ 买来 ] not in wvmodel! Use random embedding instead.
# Word: [ 刮胡子 ] not in wvmodel! Use random embedding instead.
# Word: [ 真是太 ] not in wvmodel! Use random embedding instead.
# Word: [ 我长 ] not in wvmodel! Use random embedding instead.
# Word: [ 普通人 ] not in wvmodel! Use random embedding instead.
# Word: [ 默默地 ] not in wvmodel! Use random embedding instead.
# Word: [ 霍尔 ] not in wvmodel! Use random embedding instead.
# Word: [ 爷们 ] not in wvmodel! Use random embedding instead.
# Word: [ 冰棍 ] not in wvmodel! Use random embedding instead.
# Word: [ 带上 ] not in wvmodel! Use random embedding instead.
# Word: [ 阿试 ] not in wvmodel! Use random embedding instead.
# Word: [ 体育课 ] not in wvmodel! Use random embedding instead.
# Word: [ 死后 ] not in wvmodel! Use random embedding instead.
# Word: [ 人问 ] not in wvmodel! Use random embedding instead.
# Word: [ 好意思 ] not in wvmodel! Use random embedding instead.
# Word: [ 这篇 ] not in wvmodel! Use random embedding instead.
# Word: [ 看不出来 ] not in wvmodel! Use random embedding instead.
# Word: [ 半小时 ] not in wvmodel! Use random embedding instead.
# Word: [ 家门口 ] not in wvmodel! Use random embedding instead.
# Word: [ 惊呼 ] not in wvmodel! Use random embedding instead.
# Word: [ 家庭主妇 ] not in wvmodel! Use random embedding instead.
# Word: [ 公交 ] not in wvmodel! Use random embedding instead.
# Word: [ 太丑 ] not in wvmodel! Use random embedding instead.
# Word: [ 一面镜子 ] not in wvmodel! Use random embedding instead.
# Word: [ 眼镜蛇 ] not in wvmodel! Use random embedding instead.
# Word: [ 换衣服 ] not in wvmodel! Use random embedding instead.
# Word: [ 很丑 ] not in wvmodel! Use random embedding instead.
# Word: [ 尼玛 ] not in wvmodel! Use random embedding instead.
# Word: [ 保险柜 ] not in wvmodel! Use random embedding instead.
# Word: [ 醒来时 ] not in wvmodel! Use random embedding instead.
# Word: [ 无线电 ] not in wvmodel! Use random embedding instead.
# Word: [ 坏消息 ] not in wvmodel! Use random embedding instead.
# Word: [ 多好 ] not in wvmodel! Use random embedding instead.
# Word: [ 作文题目 ] not in wvmodel! Use random embedding instead.
# Word: [ 背着 ] not in wvmodel! Use random embedding instead.
# Word: [ 一栏 ] not in wvmodel! Use random embedding instead.
# Word: [ 顺口 ] not in wvmodel! Use random embedding instead.
# Word: [ 布什 ] not in wvmodel! Use random embedding instead.
# Word: [ 公厕 ] not in wvmodel! Use random embedding instead.
# Word: [ 玩游戏 ] not in wvmodel! Use random embedding instead.
# Word: [ 发来 ] not in wvmodel! Use random embedding instead.
# Word: [ 考试成绩 ] not in wvmodel! Use random embedding instead.
# Word: [ 我开 ] not in wvmodel! Use random embedding instead.
# Word: [ 过日子 ] not in wvmodel! Use random embedding instead.
# Word: [ 解决问题 ] not in wvmodel! Use random embedding instead.
# Word: [ 比萨饼 ] not in wvmodel! Use random embedding instead.
# Word: [ 当着 ] not in wvmodel! Use random embedding instead.
# Word: [ 杂货店 ] not in wvmodel! Use random embedding instead.
# Word: [ 航班 ] not in wvmodel! Use random embedding instead.
# Word: [ 这一 ] not in wvmodel! Use random embedding instead.
# Word: [ 门卫 ] not in wvmodel! Use random embedding instead.
# Word: [ 归来 ] not in wvmodel! Use random embedding instead.
# Word: [ 少妇 ] not in wvmodel! Use random embedding instead.
# Word: [ 搭讪 ] not in wvmodel! Use random embedding instead.
# Word: [ 其妻 ] not in wvmodel! Use random embedding instead.
# Word: [ 两倍 ] not in wvmodel! Use random embedding instead.
# Word: [ 诸葛亮 ] not in wvmodel! Use random embedding instead.
# Word: [ 薯片 ] not in wvmodel! Use random embedding instead.
# Word: [ 普通话 ] not in wvmodel! Use random embedding instead.
# Word: [ 这么久 ] not in wvmodel! Use random embedding instead.
# Word: [ 那一刻 ] not in wvmodel! Use random embedding instead.
# Word: [ 一个班 ] not in wvmodel! Use random embedding instead.
# Word: [ 吃屎 ] not in wvmodel! Use random embedding instead.
# Word: [ 犹太人 ] not in wvmodel! Use random embedding instead.
# Word: [ 摇摇头 ] not in wvmodel! Use random embedding instead.
# Word: [ 他妈 ] not in wvmodel! Use random embedding instead.
# Word: [ 我成 ] not in wvmodel! Use random embedding instead.
# Word: [ 狗狗 ] not in wvmodel! Use random embedding instead.
# Word: [ 更快 ] not in wvmodel! Use random embedding instead.
# Word: [ 建筑师 ] not in wvmodel! Use random embedding instead.
# Word: [ 夫妻俩 ] not in wvmodel! Use random embedding instead.
# Word: [ 见状 ] not in wvmodel! Use random embedding instead.
# Word: [ 手术室 ] not in wvmodel! Use random embedding instead.
# Word: [ 足球赛 ] not in wvmodel! Use random embedding instead.
# Word: [ 该生 ] not in wvmodel! Use random embedding instead.
# Word: [ 一到 ] not in wvmodel! Use random embedding instead.
# Word: [ 床前 ] not in wvmodel! Use random embedding instead.
# Word: [ 改为 ] not in wvmodel! Use random embedding instead.
# Word: [ 做个 ] not in wvmodel! Use random embedding instead.
# Word: [ 太小 ] not in wvmodel! Use random embedding instead.
# Word: [ 空中小姐 ] not in wvmodel! Use random embedding instead.
# Word: [ 有种 ] not in wvmodel! Use random embedding instead.
# Word: [ 亮亮 ] not in wvmodel! Use random embedding instead.
# Word: [ 这会 ] not in wvmodel! Use random embedding instead.
# Word: [ 国际象棋 ] not in wvmodel! Use random embedding instead.
# Word: [ 牛肉面 ] not in wvmodel! Use random embedding instead.
# Word: [ 捂住 ] not in wvmodel! Use random embedding instead.
# Word: [ 直到现在 ] not in wvmodel! Use random embedding instead.
# Word: [ 墨菲 ] not in wvmodel! Use random embedding instead.
# Word: [ 微波炉 ] not in wvmodel! Use random embedding instead.
# Word: [ 这回 ] not in wvmodel! Use random embedding instead.
# Word: [ 电线杆 ] not in wvmodel! Use random embedding instead.
# Word: [ 同一天 ] not in wvmodel! Use random embedding instead.
# Word: [ 出名 ] not in wvmodel! Use random embedding instead.
# Word: [ 喝多 ] not in wvmodel! Use random embedding instead.
# Word: [ 努力学习 ] not in wvmodel! Use random embedding instead.
# Word: [ 面膜 ] not in wvmodel! Use random embedding instead.
# Word: [ 美的 ] not in wvmodel! Use random embedding instead.
# Word: [ 围栏 ] not in wvmodel! Use random embedding instead.
# Word: [ 一上午 ] not in wvmodel! Use random embedding instead.
# Word: [ 一点儿 ] not in wvmodel! Use random embedding instead.
# Word: [ 全场 ] not in wvmodel! Use random embedding instead.
# Word: [ 女仆 ] not in wvmodel! Use random embedding instead.
# Word: [ 身旁 ] not in wvmodel! Use random embedding instead.
# Word: [ 有助于 ] not in wvmodel! Use random embedding instead.
# Word: [ 小伙伴 ] not in wvmodel! Use random embedding instead.
# Word: [ 做过 ] not in wvmodel! Use random embedding instead.
# Word: [ 菜市场 ] not in wvmodel! Use random embedding instead.
# Word: [ 学姐 ] not in wvmodel! Use random embedding instead.
# Word: [ 不买 ] not in wvmodel! Use random embedding instead.
# Word: [ 14 ] not in wvmodel! Use random embedding instead.
# Word: [ 一卷 ] not in wvmodel! Use random embedding instead.
# Word: [ qq号 ] not in wvmodel! Use random embedding instead.
# Word: [ 谈谈 ] not in wvmodel! Use random embedding instead.
# Word: [ 爱意 ] not in wvmodel! Use random embedding instead.
# Word: [ 19 ] not in wvmodel! Use random embedding instead.
# Word: [ 越长 ] not in wvmodel! Use random embedding instead.
# Word: [ 电视剧 ] not in wvmodel! Use random embedding instead.
# Word: [ 生与死 ] not in wvmodel! Use random embedding instead.
# Word: [ 另一头 ] not in wvmodel! Use random embedding instead.
# Word: [ 把门 ] not in wvmodel! Use random embedding instead.
# Word: [ 许可证 ] not in wvmodel! Use random embedding instead.
# Word: [ 胡说八道 ] not in wvmodel! Use random embedding instead.
# Word: [ 开导 ] not in wvmodel! Use random embedding instead.
# Word: [ 当官 ] not in wvmodel! Use random embedding instead.
# Word: [ 第一件 ] not in wvmodel! Use random embedding instead.
# Word: [ 女老师 ] not in wvmodel! Use random embedding instead.
# Word: [ 一百万 ] not in wvmodel! Use random embedding instead.
# Word: [ 被盗 ] not in wvmodel! Use random embedding instead.
# Word: [ 男孩儿 ] not in wvmodel! Use random embedding instead.
# Word: [ 时要 ] not in wvmodel! Use random embedding instead.
# Word: [ 一毛钱 ] not in wvmodel! Use random embedding instead.
# Word: [ 业务员 ] not in wvmodel! Use random embedding instead.
# Word: [ 他答 ] not in wvmodel! Use random embedding instead.
# Word: [ 人能 ] not in wvmodel! Use random embedding instead.
# Word: [ 两句 ] not in wvmodel! Use random embedding instead.
# Word: [ 摇尾巴 ] not in wvmodel! Use random embedding instead.
# Word: [ 不懂事 ] not in wvmodel! Use random embedding instead.
# Word: [ 二十年 ] not in wvmodel! Use random embedding instead.
# Word: [ 怒道 ] not in wvmodel! Use random embedding instead.
# Word: [ 结婚戒指 ] not in wvmodel! Use random embedding instead.
# Word: [ 计划生育 ] not in wvmodel! Use random embedding instead.
# Word: [ 旅行袋 ] not in wvmodel! Use random embedding instead.
# Word: [ 训了 ] not in wvmodel! Use random embedding instead.
# Word: [ 小卖部 ] not in wvmodel! Use random embedding instead.
# Word: [ 数钱 ] not in wvmodel! Use random embedding instead.
# Word: [ 批语 ] not in wvmodel! Use random embedding instead.
# Word: [ 数到 ] not in wvmodel! Use random embedding instead.
# Word: [ 电视台 ] not in wvmodel! Use random embedding instead.
# Word: [ 自已 ] not in wvmodel! Use random embedding instead.
# Word: [ 杰克逊 ] not in wvmodel! Use random embedding instead.
# Word: [ 看后 ] not in wvmodel! Use random embedding instead.
# Word: [ 28 ] not in wvmodel! Use random embedding instead.
# Word: [ 屁颠 ] not in wvmodel! Use random embedding instead.
# Word: [ 次日 ] not in wvmodel! Use random embedding instead.
# Word: [ 锅底 ] not in wvmodel! Use random embedding instead.
# Word: [ 闯红灯 ] not in wvmodel! Use random embedding instead.
# Word: [ 懂吗 ] not in wvmodel! Use random embedding instead.
# Word: [ 门牙 ] not in wvmodel! Use random embedding instead.
# Word: [ 中考 ] not in wvmodel! Use random embedding instead.
# Word: [ 奥迪 ] not in wvmodel! Use random embedding instead.
# Word: [ 弗洛伊德 ] not in wvmodel! Use random embedding instead.
# Word: [ 给我发 ] not in wvmodel! Use random embedding instead.
# Word: [ 带回家 ] not in wvmodel! Use random embedding instead.
# Word: [ 点击 ] not in wvmodel! Use random embedding instead.
# Word: [ 都行 ] not in wvmodel! Use random embedding instead.
# Word: [ 洗发水 ] not in wvmodel! Use random embedding instead.
# Word: [ 应聘者 ] not in wvmodel! Use random embedding instead.
# Word: [ 奥利 ] not in wvmodel! Use random embedding instead.
# Word: [ 总有一天 ] not in wvmodel! Use random embedding instead.
# Word: [ 太热 ] not in wvmodel! Use random embedding instead.
# Word: [ 没带 ] not in wvmodel! Use random embedding instead.
# Word: [ 泰坦尼克号 ] not in wvmodel! Use random embedding instead.
# Word: [ 年老 ] not in wvmodel! Use random embedding instead.
# Word: [ 监斩官 ] not in wvmodel! Use random embedding instead.
# Word: [ 发笑 ] not in wvmodel! Use random embedding instead.
# Word: [ 老同学 ] not in wvmodel! Use random embedding instead.
# Word: [ 婚后 ] not in wvmodel! Use random embedding instead.
# Word: [ 取得成功 ] not in wvmodel! Use random embedding instead.
# Word: [ 走动 ] not in wvmodel! Use random embedding instead.
# Word: [ 难吃 ] not in wvmodel! Use random embedding instead.
# Word: [ 25 ] not in wvmodel! Use random embedding instead.
# Word: [ 兜里 ] not in wvmodel! Use random embedding instead.
# Word: [ 前来 ] not in wvmodel! Use random embedding instead.
# Word: [ 脸蛋 ] not in wvmodel! Use random embedding instead.
# Word: [ 第一步 ] not in wvmodel! Use random embedding instead.
# Word: [ 不得了 ] not in wvmodel! Use random embedding instead.
# Word: [ 吃晚饭 ] not in wvmodel! Use random embedding instead.
# Word: [ 鸡腿 ] not in wvmodel! Use random embedding instead.
# Word: [ 偷东西 ] not in wvmodel! Use random embedding instead.
# Word: [ 家长会 ] not in wvmodel! Use random embedding instead.
# Word: [ 有点像 ] not in wvmodel! Use random embedding instead.
# Word: [ 气喘吁吁 ] not in wvmodel! Use random embedding instead.
# Word: [ 说错 ] not in wvmodel! Use random embedding instead.
# Word: [ 圣彼得 ] not in wvmodel! Use random embedding instead.
# Word: [ 买手机 ] not in wvmodel! Use random embedding instead.
# Word: [ 这人 ] not in wvmodel! Use random embedding instead.
# Word: [ 打车 ] not in wvmodel! Use random embedding instead.
# Word: [ 13 ] not in wvmodel! Use random embedding instead.
# Word: [ 变差 ] not in wvmodel! Use random embedding instead.
# Word: [ 之美 ] not in wvmodel! Use random embedding instead.
# Word: [ 做手术 ] not in wvmodel! Use random embedding instead.
# Word: [ 坏习惯 ] not in wvmodel! Use random embedding instead.
# Word: [ 米线 ] not in wvmodel! Use random embedding instead.
# Word: [ 很行 ] not in wvmodel! Use random embedding instead.
# Word: [ 纳税人 ] not in wvmodel! Use random embedding instead.
# Word: [ 点点头 ] not in wvmodel! Use random embedding instead.
# Word: [ 不高兴地 ] not in wvmodel! Use random embedding instead.
# Word: [ 吼道 ] not in wvmodel! Use random embedding instead.
# Word: [ 讲台 ] not in wvmodel! Use random embedding instead.
# Word: [ 我过 ] not in wvmodel! Use random embedding instead.
# Word: [ 太贵 ] not in wvmodel! Use random embedding instead.
# Word: [ 这事 ] not in wvmodel! Use random embedding instead.
# Word: [ 我错 ] not in wvmodel! Use random embedding instead.
# Word: [ 毫无疑问 ] not in wvmodel! Use random embedding instead.
# Word: [ 上星期 ] not in wvmodel! Use random embedding instead.
# Word: [ 捡起 ] not in wvmodel! Use random embedding instead.
# Word: [ 有钱人 ] not in wvmodel! Use random embedding instead.
# Word: [ 凤姐 ] not in wvmodel! Use random embedding instead.
# Word: [ 大鱼 ] not in wvmodel! Use random embedding instead.
# Word: [ 小鱼 ] not in wvmodel! Use random embedding instead.
# Word: [ 大吃一惊 ] not in wvmodel! Use random embedding instead.
# Word: [ 围观 ] not in wvmodel! Use random embedding instead.
# Word: [ 压死 ] not in wvmodel! Use random embedding instead.
# Word: [ 某生 ] not in wvmodel! Use random embedding instead.
# Word: [ 气得 ] not in wvmodel! Use random embedding instead.
# Word: [ 席间 ] not in wvmodel! Use random embedding instead.
# Word: [ 共同点 ] not in wvmodel! Use random embedding instead.
# Word: [ 惹恼 ] not in wvmodel! Use random embedding instead.
# Word: [ 彪悍 ] not in wvmodel! Use random embedding instead.
# Word: [ 停车场 ] not in wvmodel! Use random embedding instead.
# Word: [ 一阵子 ] not in wvmodel! Use random embedding instead.
# Word: [ 一块儿 ] not in wvmodel! Use random embedding instead.
# Word: [ 吓人 ] not in wvmodel! Use random embedding instead.
# Word: [ 吓死 ] not in wvmodel! Use random embedding instead.
# Word: [ 内急 ] not in wvmodel! Use random embedding instead.
# Word: [ 迈克尔 ] not in wvmodel! Use random embedding instead.
# Word: [ 杯酒 ] not in wvmodel! Use random embedding instead.
# Word: [ 悟空 ] not in wvmodel! Use random embedding instead.
# Word: [ 柜员 ] not in wvmodel! Use random embedding instead.
# Word: [ 外卖 ] not in wvmodel! Use random embedding instead.
# Word: [ 睡姿 ] not in wvmodel! Use random embedding instead.
# Word: [ 喜羊羊 ] not in wvmodel! Use random embedding instead.
# Word: [ 劝架 ] not in wvmodel! Use random embedding instead.
# Word: [ 911 ] not in wvmodel! Use random embedding instead.
# Word: [ 上放 ] not in wvmodel! Use random embedding instead.
# Word: [ 会为 ] not in wvmodel! Use random embedding instead.
# Word: [ 17 ] not in wvmodel! Use random embedding instead.
# Word: [ 许久 ] not in wvmodel! Use random embedding instead.
# Word: [ 手指头 ] not in wvmodel! Use random embedding instead.
# Word: [ 怯生生 ] not in wvmodel! Use random embedding instead.
# Word: [ 一个劲地 ] not in wvmodel! Use random embedding instead.
# Word: [ 零花钱 ] not in wvmodel! Use random embedding instead.
# Word: [ 悄悄的 ] not in wvmodel! Use random embedding instead.
# Word: [ 吃火锅 ] not in wvmodel! Use random embedding instead.
# Word: [ 同义词 ] not in wvmodel! Use random embedding instead.
# Word: [ 不可思议 ] not in wvmodel! Use random embedding instead.
# ...
# Word: [ 太猛 ] not in wvmodel! Use random embedding instead.
# Word: [ 时间机器 ] not in wvmodel! Use random embedding instead.
# Word: [ 问雄 ] not in wvmodel! Use random embedding instead.
# Word: [ 小提琴家 ] not in wvmodel! Use random embedding instead.
# Word: [ 艾萨克 ] not in wvmodel! Use random embedding instead.
# Word: [ 挟着 ] not in wvmodel! Use random embedding instead.
# Word: [ 那可真 ] not in wvmodel! Use random embedding instead.
# Word: [ 间接原因 ] not in wvmodel! Use random embedding instead.
# Word: [ 回床 ] not in wvmodel! Use random embedding instead.
# Word: [ 词儿 ] not in wvmodel! Use random embedding instead.
# Word: [ 示好 ] not in wvmodel! Use random embedding instead.
# Word: [ 嘻皮笑脸 ] not in wvmodel! Use random embedding instead.
# Word: [ 默不作声 ] not in wvmodel! Use random embedding instead.
# Word: [ 最具 ] not in wvmodel! Use random embedding instead.
# Word: [ 借记卡 ] not in wvmodel! Use random embedding instead.
# Word: [ 卧梅 ] not in wvmodel! Use random embedding instead.
# Word: [ 闻花 ] not in wvmodel! Use random embedding instead.
# Word: [ 卧枝伤 ] not in wvmodel! Use random embedding instead.
# Word: [ 邀闻 ] not in wvmodel! Use random embedding instead.
# Word: [ 石碎 ] not in wvmodel! Use random embedding instead.
# Word: [ 卧湿 ] not in wvmodel! Use random embedding instead.
# Word: [ 达春绿 ] not in wvmodel! Use random embedding instead.
# Word: [ 777 ] not in wvmodel! Use random embedding instead.
# Word: [ 停机位 ] not in wvmodel! Use random embedding instead.
# Word: [ 对金 ] not in wvmodel! Use random embedding instead.
# Word: [ 亲和力 ] not in wvmodel! Use random embedding instead.
# Word: [ 熟女 ] not in wvmodel! Use random embedding instead.
# Word: [ 妈要 ] not in wvmodel! Use random embedding instead.
# Word: [ 洪涛 ] not in wvmodel! Use random embedding instead.
# Word: [ 方片 ] not in wvmodel! Use random embedding instead.
# Word: [ 不使 ] not in wvmodel! Use random embedding instead.
# Word: [ 分层 ] not in wvmodel! Use random embedding instead.
# Word: [ 资本主义 ] not in wvmodel! Use random embedding instead.
# Word: [ 一万里 ] not in wvmodel! Use random embedding instead.
# Word: [ 榨出 ] not in wvmodel! Use random embedding instead.
# Word: [ 性侵 ] not in wvmodel! Use random embedding instead.
# Word: [ 名誉扫地 ] not in wvmodel! Use random embedding instead.
# Word: [ 环卫工人 ] not in wvmodel! Use random embedding instead.
# Word: [ 上一年 ] not in wvmodel! Use random embedding instead.
# Word: [ 第九名 ] not in wvmodel! Use random embedding instead.
# Word: [ 非考 ] not in wvmodel! Use random embedding instead.
# Word: [ 蓬元帅 ] not in wvmodel! Use random embedding instead.
# Word: [ 放鞭炮 ] not in wvmodel! Use random embedding instead.
# Word: [ 只能靠 ] not in wvmodel! Use random embedding instead.
# Word: [ 金毛 ] not in wvmodel! Use random embedding instead.
# Word: [ 悲凉 ] not in wvmodel! Use random embedding instead.
# Word: [ 下厨房 ] not in wvmodel! Use random embedding instead.
# Word: [ 配件厂 ] not in wvmodel! Use random embedding instead.
# Word: [ 配牛 ] not in wvmodel! Use random embedding instead.
# Word: [ 绕道而行 ] not in wvmodel! Use random embedding instead.
# Word: [ 摄像机 ] not in wvmodel! Use random embedding instead.
# Word: [ 蚕蛹 ] not in wvmodel! Use random embedding instead.
# Word: [ 经济危机 ] not in wvmodel! Use random embedding instead.
# Word: [ 只会用 ] not in wvmodel! Use random embedding instead.
# Word: [ 解不开 ] not in wvmodel! Use random embedding instead.
# Word: [ 加湿器 ] not in wvmodel! Use random embedding instead.
# Word: [ 除湿机 ] not in wvmodel! Use random embedding instead.
# Word: [ 累点 ] not in wvmodel! Use random embedding instead.
# Word: [ 河神 ] not in wvmodel! Use random embedding instead.
# Word: [ 失声痛哭 ] not in wvmodel! Use random embedding instead.
# Word: [ 收上去 ] not in wvmodel! Use random embedding instead.
# Word: [ 说行 ] not in wvmodel! Use random embedding instead.
# Word: [ 成本价 ] not in wvmodel! Use random embedding instead.
# Word: [ 折扣价 ] not in wvmodel! Use random embedding instead.
# Word: [ 杨先生 ] not in wvmodel! Use random embedding instead.
# Word: [ 泥包 ] not in wvmodel! Use random embedding instead.
# Word: [ 泥浆 ] not in wvmodel! Use random embedding instead.
# Word: [ 数羊 ] not in wvmodel! Use random embedding instead.
# Word: [ 第一组 ] not in wvmodel! Use random embedding instead.
# Word: [ 吻别 ] not in wvmodel! Use random embedding instead.
# Word: [ 细菌学家 ] not in wvmodel! Use random embedding instead.
# Word: [ 没腿 ] not in wvmodel! Use random embedding instead.
# Word: [ 暗物质 ] not in wvmodel! Use random embedding instead.
# Word: [ 时所 ] not in wvmodel! Use random embedding instead.
# Word: [ 只演 ] not in wvmodel! Use random embedding instead.
# Word: [ 女答 ] not in wvmodel! Use random embedding instead.
# Word: [ 已生 ] not in wvmodel! Use random embedding instead.
# Word: [ 副处 ] not in wvmodel! Use random embedding instead.
# Word: [ 对守 ] not in wvmodel! Use random embedding instead.
# Word: [ 仰面朝天 ] not in wvmodel! Use random embedding instead.
# Word: [ 红日 ] not in wvmodel! Use random embedding instead.
# Word: [ 铁甲武士 ] not in wvmodel! Use random embedding instead.
# Word: [ 树边 ] not in wvmodel! Use random embedding instead.
# Word: [ 对母 ] not in wvmodel! Use random embedding instead.
# Word: [ 接来 ] not in wvmodel! Use random embedding instead.
# Word: [ 回心转意 ] not in wvmodel! Use random embedding instead.
# Word: [ 接回来 ] not in wvmodel! Use random embedding instead.
# Word: [ 伤自尊 ] not in wvmodel! Use random embedding instead.
# Word: [ 法货 ] not in wvmodel! Use random embedding instead.
# Word: [ 以人为本 ] not in wvmodel! Use random embedding instead.
# Word: [ 开裆 ] not in wvmodel! Use random embedding instead.
# Word: [ 撑破 ] not in wvmodel! Use random embedding instead.
# Word: [ 抽人 ] not in wvmodel! Use random embedding instead.
# Word: [ 起薪时 ] not in wvmodel! Use random embedding instead.
# Word: [ 细条 ] not in wvmodel! Use random embedding instead.
# Word: [ 退税 ] not in wvmodel! Use random embedding instead.
# Word: [ 如获至宝 ] not in wvmodel! Use random embedding instead.
# Word: [ 你造 ] not in wvmodel! Use random embedding instead.
# Word: [ 二十只 ] not in wvmodel! Use random embedding instead.
# Word: [ 十二属相 ] not in wvmodel! Use random embedding instead.
# Word: [ 恢复健康 ] not in wvmodel! Use random embedding instead.
# Word: [ 致力于 ] not in wvmodel! Use random embedding instead.
# Word: [ 不可分割 ] not in wvmodel! Use random embedding instead.
# Word: [ 闪闪发光 ] not in wvmodel! Use random embedding instead.
# Word: [ 脂肪肝 ] not in wvmodel! Use random embedding instead.
# Word: [ 臀围 ] not in wvmodel! Use random embedding instead.
# Word: [ 比例失调 ] not in wvmodel! Use random embedding instead.
# Word: [ 太师 ] not in wvmodel! Use random embedding instead.
# Word: [ 闻言 ] not in wvmodel! Use random embedding instead.
# Word: [ 没房 ] not in wvmodel! Use random embedding instead.
# Word: [ 没车 ] not in wvmodel! Use random embedding instead.
# Word: [ 献爱心 ] not in wvmodel! Use random embedding instead.
# Word: [ 童年时代 ] not in wvmodel! Use random embedding instead.
# Word: [ 维护者 ] not in wvmodel! Use random embedding instead.
# Word: [ 满不在乎 ] not in wvmodel! Use random embedding instead.
# Word: [ 大步流星 ] not in wvmodel! Use random embedding instead.
# Word: [ 壮劳力 ] not in wvmodel! Use random embedding instead.
# Word: [ 怎么弄 ] not in wvmodel! Use random embedding instead.
# Word: [ 我亲 ] not in wvmodel! Use random embedding instead.
# Word: [ 健康活泼 ] not in wvmodel! Use random embedding instead.
# Word: [ 特么特 ] not in wvmodel! Use random embedding instead.
# Word: [ 三双 ] not in wvmodel! Use random embedding instead.
# Word: [ 进价 ] not in wvmodel! Use random embedding instead.
# Word: [ 不买烟 ] not in wvmodel! Use random embedding instead.
# Word: [ 纷纷表示 ] not in wvmodel! Use random embedding instead.
# Word: [ 刹那间 ] not in wvmodel! Use random embedding instead.
# Word: [ 借机 ] not in wvmodel! Use random embedding instead.
# Word: [ 卖弄 ] not in wvmodel! Use random embedding instead.
# Word: [ 规规矩矩 ] not in wvmodel! Use random embedding instead.
# Word: [ 维德 ] not in wvmodel! Use random embedding instead.
# Word: [ 校对员 ] not in wvmodel! Use random embedding instead.
# Word: [ 驱魔人 ] not in wvmodel! Use random embedding instead.
# Word: [ 后写 ] not in wvmodel! Use random embedding instead.
# Word: [ 失乐园 ] not in wvmodel! Use random embedding instead.
# Word: [ 小云 ] not in wvmodel! Use random embedding instead.
# Word: [ 塔罗牌 ] not in wvmodel! Use random embedding instead.
# Word: [ 同花顺 ] not in wvmodel! Use random embedding instead.
# Word: [ 五十马克 ] not in wvmodel! Use random embedding instead.
# Word: [ 早产 ] not in wvmodel! Use random embedding instead.
# Word: [ 脱裤子 ] not in wvmodel! Use random embedding instead.
# Word: [ 弗林特 ] not in wvmodel! Use random embedding instead.
# Word: [ 属灵 ] not in wvmodel! Use random embedding instead.
# Word: [ 装睡 ] not in wvmodel! Use random embedding instead.
# Word: [ 越难 ] not in wvmodel! Use random embedding instead.
# Word: [ 小明来 ] not in wvmodel! Use random embedding instead.
# Word: [ 出租汽车 ] not in wvmodel! Use random embedding instead.
# Word: [ 临危不惧 ] not in wvmodel! Use random embedding instead.
# Word: [ 爱拉芳 ] not in wvmodel! Use random embedding instead.
# Word: [ 总带 ] not in wvmodel! Use random embedding instead.
# Word: [ 所爱 ] not in wvmodel! Use random embedding instead.
# Word: [ 杂技演员 ] not in wvmodel! Use random embedding instead.
# Word: [ 莫索里尼 ] not in wvmodel! Use random embedding instead.
# Word: [ 树愈静 ] not in wvmodel! Use random embedding instead.
# Word: [ 愈恋 ] not in wvmodel! Use random embedding instead.
# Word: [ 55 ] not in wvmodel! Use random embedding instead.
# Word: [ 戏票 ] not in wvmodel! Use random embedding instead.
# Word: [ 被犬决 ] not in wvmodel! Use random embedding instead.
# Word: [ 认认真真 ] not in wvmodel! Use random embedding instead.
# Word: [ 满满的 ] not in wvmodel! Use random embedding instead.
# Word: [ 第三行 ] not in wvmodel! Use random embedding instead.
# Word: [ 第七个 ] not in wvmodel! Use random embedding instead.
# Word: [ 变平 ] not in wvmodel! Use random embedding instead.
# Word: [ 时吵 ] not in wvmodel! Use random embedding instead.
# Word: [ 世界性 ] not in wvmodel! Use random embedding instead.
# Word: [ 同时代 ] not in wvmodel! Use random embedding instead.
# Word: [ 主办人 ] not in wvmodel! Use random embedding instead.
# Word: [ 马夫人 ] not in wvmodel! Use random embedding instead.
# Word: [ 声是 ] not in wvmodel! Use random embedding instead.
# Word: [ 门面 ] not in wvmodel! Use random embedding instead.
# Word: [ 急急 ] not in wvmodel! Use random embedding instead.
# Word: [ 我演 ] not in wvmodel! Use random embedding instead.
# Word: [ 换人 ] not in wvmodel! Use random embedding instead.
# Word: [ 剑客 ] not in wvmodel! Use random embedding instead.
# Word: [ 鸡群 ] not in wvmodel! Use random embedding instead.
# Word: [ 舞剑 ] not in wvmodel! Use random embedding instead.
# Word: [ h7n9 ] not in wvmodel! Use random embedding instead.
# Word: [ 断送 ] not in wvmodel! Use random embedding instead.
# Word: [ 活计 ] not in wvmodel! Use random embedding instead.
# Word: [ 一百辆 ] not in wvmodel! Use random embedding instead.
# Word: [ 伐木工 ] not in wvmodel! Use random embedding instead.
# Word: [ 工作鞋 ] not in wvmodel! Use random embedding instead.
# Word: [ 最烈 ] not in wvmodel! Use random embedding instead.
# Word: [ 篮球赛 ] not in wvmodel! Use random embedding instead.
# Word: [ 上届 ] not in wvmodel! Use random embedding instead.
# Word: [ 以助 ] not in wvmodel! Use random embedding instead.
# Word: [ 声威 ] not in wvmodel! Use random embedding instead.
# Word: [ 边帮 ] not in wvmodel! Use random embedding instead.
# Word: [ 修脸 ] not in wvmodel! Use random embedding instead.
# Word: [ 出尔反尔 ] not in wvmodel! Use random embedding instead.
# Word: [ 众叛亲离 ] not in wvmodel! Use random embedding instead.
# Word: [ 乱花钱 ] not in wvmodel! Use random embedding instead.
# Word: [ 意外事故 ] not in wvmodel! Use random embedding instead.
# Word: [ 两辆 ] not in wvmodel! Use random embedding instead.
# Word: [ 黛比 ] not in wvmodel! Use random embedding instead.
# Word: [ 会议记录 ] not in wvmodel! Use random embedding instead.
# Word: [ 那怪 ] not in wvmodel! Use random embedding instead.
# Word: [ 特惠 ] not in wvmodel! Use random embedding instead.
# Word: [ 双下巴 ] not in wvmodel! Use random embedding instead.
# Word: [ 机取 ] not in wvmodel! Use random embedding instead.
# Word: [ 巨怪 ] not in wvmodel! Use random embedding instead.
# Word: [ 我操 ] not in wvmodel! Use random embedding instead.
# Word: [ 机烧 ] not in wvmodel! Use random embedding instead.
# Word: [ 十四次 ] not in wvmodel! Use random embedding instead.
# Word: [ 场内 ] not in wvmodel! Use random embedding instead.
# Word: [ 较乱 ] not in wvmodel! Use random embedding instead.
# Word: [ 蠢才 ] not in wvmodel! Use random embedding instead.
# Word: [ 哪像 ] not in wvmodel! Use random embedding instead.
# Word: [ 堪称 ] not in wvmodel! Use random embedding instead.
# Word: [ 凑桌 ] not in wvmodel! Use random embedding instead.
# Word: [ 那萌 ] not in wvmodel! Use random embedding instead.
# Word: [ 血战 ] not in wvmodel! Use random embedding instead.
# Word: [ 表演艺术 ] not in wvmodel! Use random embedding instead.
# Word: [ 我准 ] not in wvmodel! Use random embedding instead.
# Word: [ 猜不出 ] not in wvmodel! Use random embedding instead.
# Word: [ 天津大学 ] not in wvmodel! Use random embedding instead.
# Word: [ 上海大学 ] not in wvmodel! Use random embedding instead.
# Word: [ 厦门大学 ] not in wvmodel! Use random embedding instead.
# Word: [ 极简 ] not in wvmodel! Use random embedding instead.
# Word: [ 天追到 ] not in wvmodel! Use random embedding instead.
# Word: [ 拔根 ] not in wvmodel! Use random embedding instead.
# Word: [ 六片 ] not in wvmodel! Use random embedding instead.
# Word: [ 练习生 ] not in wvmodel! Use random embedding instead.
# Word: [ 畏畏缩缩 ] not in wvmodel! Use random embedding instead.
# Word: [ 笑容满面 ] not in wvmodel! Use random embedding instead.
# Word: [ 乔帮主 ] not in wvmodel! Use random embedding instead.
# Word: [ 抢个 ] not in wvmodel! Use random embedding instead.
# Word: [ 心里话 ] not in wvmodel! Use random embedding instead.
# Word: [ 启迪 ] not in wvmodel! Use random embedding instead.
# Word: [ 快地 ] not in wvmodel! Use random embedding instead.
# Word: [ 张家 ] not in wvmodel! Use random embedding instead.
# Word: [ 出于意外 ] not in wvmodel! Use random embedding instead.
# Word: [ 四时 ] not in wvmodel! Use random embedding instead.
# Word: [ 满床 ] not in wvmodel! Use random embedding instead.
# Word: [ 太软弱 ] not in wvmodel! Use random embedding instead.
# Word: [ 海蒂 ] not in wvmodel! Use random embedding instead.
# Word: [ 小黄瓜 ] not in wvmodel! Use random embedding instead.
# Word: [ 小碎 ] not in wvmodel! Use random embedding instead.
# Word: [ 头碎 ] not in wvmodel! Use random embedding instead.
# Word: [ 但前 ] not in wvmodel! Use random embedding instead.
# Word: [ 他出 ] not in wvmodel! Use random embedding instead.
# Word: [ 俾格米 ] not in wvmodel! Use random embedding instead.
# Word: [ 新婚姻法 ] not in wvmodel! Use random embedding instead.
# Word: [ 不坑 ] not in wvmodel! Use random embedding instead.
# Word: [ 改坑 ] not in wvmodel! Use random embedding instead.
# Word: [ 建设银行 ] not in wvmodel! Use random embedding instead.
# Word: [ 发传单 ] not in wvmodel! Use random embedding instead.
# Word: [ 训练营 ] not in wvmodel! Use random embedding instead.
# Word: [ 起诉书 ] not in wvmodel! Use random embedding instead.
# Word: [ 犯了罪 ] not in wvmodel! Use random embedding instead.
# Word: [ 一挺 ] not in wvmodel! Use random embedding instead.
# Word: [ 哈韩 ] not in wvmodel! Use random embedding instead.
# Word: [ 老白 ] not in wvmodel! Use random embedding instead.
# Word: [ 老白大怒 ] not in wvmodel! Use random embedding instead.
# Word: [ 人流量 ] not in wvmodel! Use random embedding instead.
# Word: [ 44 ] not in wvmodel! Use random embedding instead.
# Word: [ 圣地亚哥 ] not in wvmodel! Use random embedding instead.
# Word: [ 很久以前 ] not in wvmodel! Use random embedding instead.
# Word: [ 大鼻子 ] not in wvmodel! Use random embedding instead.
# Word: [ 比马 ] not in wvmodel! Use random embedding instead.
# Word: [ 喜力 ] not in wvmodel! Use random embedding instead.
# Word: [ 吸压 ] not in wvmodel! Use random embedding instead.
# Word: [ 爆排 ] not in wvmodel! Use random embedding instead.
# Word: [ 横联 ] not in wvmodel! Use random embedding instead.
# Word: [ 二百五十 ] not in wvmodel! Use random embedding instead.
# Word: [ 合用 ] not in wvmodel! Use random embedding instead.
# Word: [ 地吻 ] not in wvmodel! Use random embedding instead.
# Word: [ 落山 ] not in wvmodel! Use random embedding instead.
# 完成！
# Embedding matrix shape:
#  (30001, 300)

# %%
import keras
from keras.models import Sequential, Model
from keras.layers import Input, Dense, GRU, LSTM, Activation, Dropout, Embedding
from keras.layers import Multiply, Concatenate, Dot

from sklearn.metrics import f1_score

# lstm
wv_dim = 300
n_timesteps = maxlen
inputs = Input(shape=(maxlen,))
embedding_sequences = Embedding(vocab_size+1, wv_dim, input_length=maxlen, weights=[embedding_matrix])(inputs)
lstm = LSTM(128, return_sequences= False)(embedding_sequences)
l = Dense(128, activation="tanh")(lstm)
l = Dropout(0.5)(l)
l = Dense(2, activation="softmax")(l)
m = Model(inputs, l)
m.summary()
m.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
m.fit(X_train, y_train, epochs=10, batch_size=32, validation_split=0.2)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0901 18:21:27.335547 144828 deprecation_wrapper.py:119] From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0901 18:21:27.347527 144828 deprecation_wrapper.py:119] From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0901 18:21:27.349545 144828 deprecation_wrapper.py:119] From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0901 18:21:27.355536 144828 deprecation_wrapper.py:119] From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0901 18:21:27.356534 144828 deprecation_wrapper.py:119] From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0901 18:21:27.751450 144828 deprecation.py:506] From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0901 18:21:27.770400 144828 deprecation_wrapper.py:119] From D:\Anaconda3\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0901 18:21:27.792388 144828 deprecation.py:323] From D:\Anaconda3\lib\site-packages\tensorflow\python\ops\nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 25)                0
# _________________________________________________________________
# embedding_1 (Embedding)      (None, 25, 300)           9000300
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 128)               219648
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 9,236,718
# Trainable params: 9,236,718
# Non-trainable params: 0
# _________________________________________________________________
# Train on 13136 samples, validate on 3284 samples
# Epoch 1/10
#   576/13136 [>.............................] - ETA: 1:02 - loss: 0.5663 - acc: 0.6892
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-79f1ccac92b6> in <module>
#      18 m.summary()
#      19 m.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# ---> 20 m.fit(X_train, y_train, epochs=10, batch_size=32, validation_split=0.2)
#
# D:\Anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# D:\Anaconda3\lib\site-packages\keras\engine\training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# D:\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1456         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1457                                                self._handle, args,
# -> 1458                                                run_metadata_ptr)
#    1459         if run_metadata:
#    1460           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:
