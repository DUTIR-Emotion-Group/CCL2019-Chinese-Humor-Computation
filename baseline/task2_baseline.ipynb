# %%
import pandas as pd

train = pd.read_csv('task2_train.csv')
test = pd.read_csv('task2_test.csv')

# print(train['label'].value_counts())
# print(test['label'].value_counts())
# print(len(train))
# print(len(test))

# %%
import jieba
import numpy as np

train['sen_cut'] = train['joke'].apply(jieba.lcut)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\ADMINI~1\AppData\Local\Temp\jieba.cache
# Loading model cost 0.604 seconds.
# Prefix dict has been built succesfully.

# %%
X_train = train['sen_cut'].apply(lambda x: ' '.join(x)).tolist()
y_train = pd.get_dummies((np.asarray(train["label"])))
text = np.array(X_train)

# %%
from keras.preprocessing.text import Tokenizer
from keras_preprocessing.sequence import pad_sequences
import time

vocab_size = 50000
maxlen = 70

print("开始统计语料的词频信息...")
t = Tokenizer(vocab_size)
t.fit_on_texts(text)
word_index = t.word_index
print('完整的字典大小：', len(word_index))

print("开始序列化句子...")
X_train = t.texts_to_sequences(X_train)
print("开始对齐句子序列...")
X_train = pad_sequences(X_train, maxlen=maxlen, padding='post')
print("完成！")
# Out:
# Using TensorFlow backend.
# 开始统计语料的词频信息...
# 完整的字典大小： 60898
# 开始序列化句子...
# 开始对齐句子序列...
# 完成！

# %%
import copy

small_word_index = copy.deepcopy(word_index) # 防止原来的字典被改变
x = list(t.word_counts.items())
s = sorted(x, key=lambda p:p[1], reverse=True)
print("移除word_index字典中的低频词...")
for item in s[vocab_size:]:
    small_word_index.pop(item[0]) # 对字典pop
print("完成！")
print(len(small_word_index))
print(len(word_index))
# Out:
# 移除word_index字典中的低频词...
# 完成！
# 50000
# 60898

# %%
print(type(X_train))
print(type(y_train))
# Out:
# <class 'numpy.ndarray'>
# <class 'pandas.core.frame.DataFrame'>

# %%
import gensim

model_file = 'E:/embedding/wiki.zh.vec' # input your file path
print("加载Word2Vec模型...")
wv_model = gensim.models.KeyedVectors.load_word2vec_format(model_file, binary=False)
# Out:
# 加载Word2Vec模型...

# %%
embedding_matrix = np.random.uniform(size=(vocab_size+1,300))
print("构建embedding_matrix...")
for word, index in small_word_index.items():
    try:
        word_vector = wv_model[word]
        embedding_matrix[index] = word_vector
    except:
        print("Word: [",word,"] not in wvmodel! Use random embedding instead.")
print("完成！")
print("Embedding matrix shape:\n",embedding_matrix.shape)
# Out:
# 构建embedding_matrix...
# Word: [ “ ] not in wvmodel! Use random embedding instead.
# Word: [ ” ] not in wvmodel! Use random embedding instead.
# Word: [ 阿凡提 ] not in wvmodel! Use random embedding instead.
# Word: [ ’ ] not in wvmodel! Use random embedding instead.
# Word: [ 地说 ] not in wvmodel! Use random embedding instead.
# Word: [ 两个 ] not in wvmodel! Use random embedding instead.
# Word: [ 有个 ] not in wvmodel! Use random embedding instead.
# Word: [ 这是 ] not in wvmodel! Use random embedding instead.
# Word: [ 答道 ] not in wvmodel! Use random embedding instead.
# Word: [ 哥们 ] not in wvmodel! Use random embedding instead.
# Word: [ 一会儿 ] not in wvmodel! Use random embedding instead.
# Word: [ 看着 ] not in wvmodel! Use random embedding instead.
# Word: [ 地问 ] not in wvmodel! Use random embedding instead.
# Word: [ 服务员 ] not in wvmodel! Use random embedding instead.
# Word: [ 第二天 ] not in wvmodel! Use random embedding instead.
# Word: [ 三个 ] not in wvmodel! Use random embedding instead.
# Word: [ 5 ] not in wvmodel! Use random embedding instead.
# Word: [ 1 ] not in wvmodel! Use random embedding instead.
# Word: [ 10 ] not in wvmodel! Use random embedding instead.
# Word: [ 3 ] not in wvmodel! Use random embedding instead.
# Word: [ 只见 ] not in wvmodel! Use random embedding instead.
# Word: [ 指着 ] not in wvmodel! Use random embedding instead.
# Word: [ 2 ] not in wvmodel! Use random embedding instead.
# Word: [ 一会 ] not in wvmodel! Use random embedding instead.
# Word: [ 说完 ] not in wvmodel! Use random embedding instead.
# Word: [ 办公室 ] not in wvmodel! Use random embedding instead.
# Word: [ 怎么办 ] not in wvmodel! Use random embedding instead.
# Word: [ 老妈 ] not in wvmodel! Use random embedding instead.
# Word: [ 怎么样 ] not in wvmodel! Use random embedding instead.
# Word: [ 4 ] not in wvmodel! Use random embedding instead.
# Word: [ 还要 ] not in wvmodel! Use random embedding instead.
# Word: [ 喊道 ] not in wvmodel! Use random embedding instead.
# Word: [ 100 ] not in wvmodel! Use random embedding instead.
# Word: [ 我会 ] not in wvmodel! Use random embedding instead.
# Word: [ 年轻人 ] not in wvmodel! Use random embedding instead.
# Word: [ 每个 ] not in wvmodel! Use random embedding instead.
# Word: [ 有没有 ] not in wvmodel! Use random embedding instead.
# Word: [ 20 ] not in wvmodel! Use random embedding instead.
# Word: [ 两人 ] not in wvmodel! Use random embedding instead.
# Word: [ 一脸 ] not in wvmodel! Use random embedding instead.
# Word: [ 小男孩 ] not in wvmodel! Use random embedding instead.
# Word: [ 一辆 ] not in wvmodel! Use random embedding instead.
# Word: [ 同桌 ] not in wvmodel! Use random embedding instead.
# Word: [ 嘴里 ] not in wvmodel! Use random embedding instead.
# Word: [ 小时候 ] not in wvmodel! Use random embedding instead.
# Word: [ 6 ] not in wvmodel! Use random embedding instead.
# Word: [ 小女孩 ] not in wvmodel! Use random embedding instead.
# Word: [ 这天 ] not in wvmodel! Use random embedding instead.
# Word: [ 50 ] not in wvmodel! Use random embedding instead.
# Word: [ 四个 ] not in wvmodel! Use random embedding instead.
# Word: [ 干嘛 ] not in wvmodel! Use random embedding instead.
# Word: [ 第一个 ] not in wvmodel! Use random embedding instead.
# Word: [ 那人 ] not in wvmodel! Use random embedding instead.
# Word: [ 幼儿园 ] not in wvmodel! Use random embedding instead.
# Word: [ 脸上 ] not in wvmodel! Use random embedding instead.
# Word: [ 8 ] not in wvmodel! Use random embedding instead.
# Word: [ 县官 ] not in wvmodel! Use random embedding instead.
# Word: [ 一顿 ] not in wvmodel! Use random embedding instead.
# Word: [ 有钱 ] not in wvmodel! Use random embedding instead.
# Word: [ 没事 ] not in wvmodel! Use random embedding instead.
# Word: [ 嫁给 ] not in wvmodel! Use random embedding instead.
# Word: [ 不让 ] not in wvmodel! Use random embedding instead.
# Word: [ 售货员 ] not in wvmodel! Use random embedding instead.
# Word: [ 怎么回事 ] not in wvmodel! Use random embedding instead.
# Word: [ 自行车 ] not in wvmodel! Use random embedding instead.
# Word: [ 30 ] not in wvmodel! Use random embedding instead.
# Word: [ 你家 ] not in wvmodel! Use random embedding instead.
# Word: [ 谁知 ] not in wvmodel! Use random embedding instead.
# Word: [ 看电视 ] not in wvmodel! Use random embedding instead.
# Word: [ 小强 ] not in wvmodel! Use random embedding instead.
# Word: [ 摇头 ] not in wvmodel! Use random embedding instead.
# Word: [ 是因为 ] not in wvmodel! Use random embedding instead.
# Word: [ 7 ] not in wvmodel! Use random embedding instead.
# Word: [ 两只 ] not in wvmodel! Use random embedding instead.
# Word: [ 车上 ] not in wvmodel! Use random embedding instead.
# Word: [ 头上 ] not in wvmodel! Use random embedding instead.
# Word: [ 一瓶 ] not in wvmodel! Use random embedding instead.
# Word: [ 为啥 ] not in wvmodel! Use random embedding instead.
# Word: [ 听后 ] not in wvmodel! Use random embedding instead.
# Word: [ 写道 ] not in wvmodel! Use random embedding instead.
# Word: [ 墙上 ] not in wvmodel! Use random embedding instead.
# Word: [ 公交车 ] not in wvmodel! Use random embedding instead.
# Word: [ 一个月 ] not in wvmodel! Use random embedding instead.
# Word: [ 小张 ] not in wvmodel! Use random embedding instead.
# Word: [ 明说 ] not in wvmodel! Use random embedding instead.
# Word: [ 女同学 ] not in wvmodel! Use random embedding instead.
# Word: [ 车子 ] not in wvmodel! Use random embedding instead.
# Word: [ 就让 ] not in wvmodel! Use random embedding instead.
# Word: [ 毛驴 ] not in wvmodel! Use random embedding instead.
# Word: [ 杰克 ] not in wvmodel! Use random embedding instead.
# Word: [ 接过 ] not in wvmodel! Use random embedding instead.
# Word: [ 这件 ] not in wvmodel! Use random embedding instead.
# Word: [ 9 ] not in wvmodel! Use random embedding instead.
# Word: [ 计算机 ] not in wvmodel! Use random embedding instead.
# Word: [ 块钱 ] not in wvmodel! Use random embedding instead.
# Word: [ 干吗 ] not in wvmodel! Use random embedding instead.
# Word: [ 什么样 ] not in wvmodel! Use random embedding instead.
# Word: [ 就行了 ] not in wvmodel! Use random embedding instead.
# Word: [ 不料 ] not in wvmodel! Use random embedding instead.
# Word: [ 两天 ] not in wvmodel! Use random embedding instead.
# Word: [ 是从 ] not in wvmodel! Use random embedding instead.
# Word: [ 一场 ] not in wvmodel! Use random embedding instead.
# Word: [ 进门 ] not in wvmodel! Use random embedding instead.
# Word: [ 有次 ] not in wvmodel! Use random embedding instead.
# Word: [ 12 ] not in wvmodel! Use random embedding instead.
# Word: [ 城里 ] not in wvmodel! Use random embedding instead.
# Word: [ 递给 ] not in wvmodel! Use random embedding instead.
# Word: [ 完后 ] not in wvmodel! Use random embedding instead.
# Word: [ 女同事 ] not in wvmodel! Use random embedding instead.
# Word: [ 满脸 ] not in wvmodel! Use random embedding instead.
# Word: [ 40 ] not in wvmodel! Use random embedding instead.
# Word: [ 试试 ] not in wvmodel! Use random embedding instead.
# Word: [ 这人 ] not in wvmodel! Use random embedding instead.
# Word: [ 15 ] not in wvmodel! Use random embedding instead.
# Word: [ 半个 ] not in wvmodel! Use random embedding instead.
# Word: [ 这时候 ] not in wvmodel! Use random embedding instead.
# Word: [ 喀孜 ] not in wvmodel! Use random embedding instead.
# Word: [ 没见 ] not in wvmodel! Use random embedding instead.
# Word: [ 举手 ] not in wvmodel! Use random embedding instead.
# Word: [ 一口气 ] not in wvmodel! Use random embedding instead.
# Word: [ 树上 ] not in wvmodel! Use random embedding instead.
# Word: [ 动物园 ] not in wvmodel! Use random embedding instead.
# Word: [ 屋里 ] not in wvmodel! Use random embedding instead.
# Word: [ 立马 ] not in wvmodel! Use random embedding instead.
# Word: [ 哥们儿 ] not in wvmodel! Use random embedding instead.
# Word: [ 却是 ] not in wvmodel! Use random embedding instead.
# Word: [ 我用 ] not in wvmodel! Use random embedding instead.
# Word: [ 两位 ] not in wvmodel! Use random embedding instead.
# Word: [ 这话 ] not in wvmodel! Use random embedding instead.
# Word: [ 五个 ] not in wvmodel! Use random embedding instead.
# Word: [ 淡定 ] not in wvmodel! Use random embedding instead.
# Word: [ 那好 ] not in wvmodel! Use random embedding instead.
# Word: [ 那条 ] not in wvmodel! Use random embedding instead.
# Word: [ 1000 ] not in wvmodel! Use random embedding instead.
# Word: [ 爸妈 ] not in wvmodel! Use random embedding instead.
# Word: [ 身旁 ] not in wvmodel! Use random embedding instead.
# Word: [ 班里 ] not in wvmodel! Use random embedding instead.
# Word: [ 这家 ] not in wvmodel! Use random embedding instead.
# Word: [ 这有 ] not in wvmodel! Use random embedding instead.
# Word: [ 吼道 ] not in wvmodel! Use random embedding instead.
# Word: [ 三岁 ] not in wvmodel! Use random embedding instead.
# Word: [ 用来 ] not in wvmodel! Use random embedding instead.
# Word: [ 乙说 ] not in wvmodel! Use random embedding instead.
# Word: [ 小华 ] not in wvmodel! Use random embedding instead.
# Word: [ 走来 ] not in wvmodel! Use random embedding instead.
# Word: [ 公交 ] not in wvmodel! Use random embedding instead.
# Word: [ 快点 ] not in wvmodel! Use random embedding instead.
# Word: [ 没人 ] not in wvmodel! Use random embedding instead.
# Word: [ 毛拉 ] not in wvmodel! Use random embedding instead.
# Word: [ 200 ] not in wvmodel! Use random embedding instead.
# Word: [ 理发师 ] not in wvmodel! Use random embedding instead.
# Word: [ 身后 ] not in wvmodel! Use random embedding instead.
# Word: [ 他会 ] not in wvmodel! Use random embedding instead.
# Word: [ 一小 ] not in wvmodel! Use random embedding instead.
# Word: [ 工程师 ] not in wvmodel! Use random embedding instead.
# Word: [ 摇摇头 ] not in wvmodel! Use random embedding instead.
# Word: [ 讲台 ] not in wvmodel! Use random embedding instead.
# Word: [ 要说 ] not in wvmodel! Use random embedding instead.
# Word: [ 语文课 ] not in wvmodel! Use random embedding instead.
# Word: [ 一见 ] not in wvmodel! Use random embedding instead.
# Word: [ 两年 ] not in wvmodel! Use random embedding instead.
# Word: [ 这条 ] not in wvmodel! Use random embedding instead.
# Word: [ 邻居家 ] not in wvmodel! Use random embedding instead.
# Word: [ 0 ] not in wvmodel! Use random embedding instead.
# Word: [ 不服气 ] not in wvmodel! Use random embedding instead.
# Word: [ 有天 ] not in wvmodel! Use random embedding instead.
# Word: [ 老总 ] not in wvmodel! Use random embedding instead.
# Word: [ 河里 ] not in wvmodel! Use random embedding instead.
# Word: [ 说好 ] not in wvmodel! Use random embedding instead.
# Word: [ 公共汽车 ] not in wvmodel! Use random embedding instead.
# Word: [ 科学家 ] not in wvmodel! Use random embedding instead.
# Word: [ 其他人 ] not in wvmodel! Use random embedding instead.
# Word: [ 不一会儿 ] not in wvmodel! Use random embedding instead.
# Word: [ 我怕 ] not in wvmodel! Use random embedding instead.
# Word: [ 这句 ] not in wvmodel! Use random embedding instead.
# Word: [ 谈恋爱 ] not in wvmodel! Use random embedding instead.
# Word: [ 舍友 ] not in wvmodel! Use random embedding instead.
# Word: [ 前来 ] not in wvmodel! Use random embedding instead.
# Word: [ 一间 ] not in wvmodel! Use random embedding instead.
# Word: [ 11 ] not in wvmodel! Use random embedding instead.
# Word: [ 工作人员 ] not in wvmodel! Use random embedding instead.
# Word: [ 他俩 ] not in wvmodel! Use random embedding instead.
# Word: [ 25 ] not in wvmodel! Use random embedding instead.
# Word: [ 要钱 ] not in wvmodel! Use random embedding instead.
# Word: [ 几分钟 ] not in wvmodel! Use random embedding instead.
# Word: [ 气得 ] not in wvmodel! Use random embedding instead.
# Word: [ 服务生 ] not in wvmodel! Use random embedding instead.
# Word: [ 低声 ] not in wvmodel! Use random embedding instead.
# Word: [ 60 ] not in wvmodel! Use random embedding instead.
# Word: [ 网吧 ] not in wvmodel! Use random embedding instead.
# Word: [ 电视机 ] not in wvmodel! Use random embedding instead.
# Word: [ 发了 ] not in wvmodel! Use random embedding instead.
# Word: [ 点点头 ] not in wvmodel! Use random embedding instead.
# Word: [ 前天 ] not in wvmodel! Use random embedding instead.
# Word: [ 数学老师 ] not in wvmodel! Use random embedding instead.
# Word: [ 我刚 ] not in wvmodel! Use random embedding instead.
# Word: [ 河边 ] not in wvmodel! Use random embedding instead.
# Word: [ 第一天 ] not in wvmodel! Use random embedding instead.
# Word: [ 小儿子 ] not in wvmodel! Use random embedding instead.
# Word: [ 500 ] not in wvmodel! Use random embedding instead.
# Word: [ 几位 ] not in wvmodel! Use random embedding instead.
# Word: [ 想着 ] not in wvmodel! Use random embedding instead.
# Word: [ 一本正经 ] not in wvmodel! Use random embedding instead.
# Word: [ 这货 ] not in wvmodel! Use random embedding instead.
# Word: [ 进城 ] not in wvmodel! Use random embedding instead.
# Word: [ 80 ] not in wvmodel! Use random embedding instead.
# Word: [ 关上 ] not in wvmodel! Use random embedding instead.
# Word: [ 老李 ] not in wvmodel! Use random embedding instead.
# Word: [ 营业员 ] not in wvmodel! Use random embedding instead.
# Word: [ 千万别 ] not in wvmodel! Use random embedding instead.
# Word: [ 问问 ] not in wvmodel! Use random embedding instead.
# Word: [ 店里 ] not in wvmodel! Use random embedding instead.
# Word: [ 接电话 ] not in wvmodel! Use random embedding instead.
# Word: [ 看过 ] not in wvmodel! Use random embedding instead.
# Word: [ 巴依 ] not in wvmodel! Use random embedding instead.
# Word: [ 转过 ] not in wvmodel! Use random embedding instead.
# Word: [ 卫生间 ] not in wvmodel! Use random embedding instead.
# Word: [ 一段时间 ] not in wvmodel! Use random embedding instead.
# Word: [ 用手 ] not in wvmodel! Use random embedding instead.
# Word: [ 本书 ] not in wvmodel! Use random embedding instead.
# Word: [ 男同学 ] not in wvmodel! Use random embedding instead.
# Word: [ 打断 ] not in wvmodel! Use random embedding instead.
# Word: [ 睡不着 ] not in wvmodel! Use random embedding instead.
# Word: [ 推销员 ] not in wvmodel! Use random embedding instead.
# Word: [ 小女儿 ] not in wvmodel! Use random embedding instead.
# Word: [ 小李 ] not in wvmodel! Use random embedding instead.
# Word: [ 毫不犹豫 ] not in wvmodel! Use random embedding instead.
# Word: [ 每当 ] not in wvmodel! Use random embedding instead.
# Word: [ 一盘 ] not in wvmodel! Use random embedding instead.
# Word: [ 却说 ] not in wvmodel! Use random embedding instead.
# Word: [ 不一会 ] not in wvmodel! Use random embedding instead.
# Word: [ 丘吉尔 ] not in wvmodel! Use random embedding instead.
# Word: [ 小丽 ] not in wvmodel! Use random embedding instead.
# Word: [ 打麻将 ] not in wvmodel! Use random embedding instead.
# Word: [ 那头 ] not in wvmodel! Use random embedding instead.
# Word: [ 朋友家 ] not in wvmodel! Use random embedding instead.
# Word: [ 随口 ] not in wvmodel! Use random embedding instead.
# Word: [ 从来不 ] not in wvmodel! Use random embedding instead.
# Word: [ 布什 ] not in wvmodel! Use random embedding instead.
# Word: [ 连长 ] not in wvmodel! Use random embedding instead.
# Word: [ 吐温 ] not in wvmodel! Use random embedding instead.
# Word: [ 送来 ] not in wvmodel! Use random embedding instead.
# Word: [ 神经病 ] not in wvmodel! Use random embedding instead.
# Word: [ 一家人 ] not in wvmodel! Use random embedding instead.
# Word: [ 小猪 ] not in wvmodel! Use random embedding instead.
# Word: [ 我俩 ] not in wvmodel! Use random embedding instead.
# Word: [ 小家伙 ] not in wvmodel! Use random embedding instead.
# Word: [ 车里 ] not in wvmodel! Use random embedding instead.
# Word: [ 小红 ] not in wvmodel! Use random embedding instead.
# Word: [ 这回 ] not in wvmodel! Use random embedding instead.
# Word: [ 李四 ] not in wvmodel! Use random embedding instead.
# Word: [ 大吼 ] not in wvmodel! Use random embedding instead.
# Word: [ 还会 ] not in wvmodel! Use random embedding instead.
# Word: [ 哲学家 ] not in wvmodel! Use random embedding instead.
# Word: [ 摩托车 ] not in wvmodel! Use random embedding instead.
# Word: [ 夫妻俩 ] not in wvmodel! Use random embedding instead.
# Word: [ 全场 ] not in wvmodel! Use random embedding instead.
# Word: [ 大为 ] not in wvmodel! Use random embedding instead.
# Word: [ 18 ] not in wvmodel! Use random embedding instead.
# Word: [ 发现自己 ] not in wvmodel! Use random embedding instead.
# Word: [ 咱俩 ] not in wvmodel! Use random embedding instead.
# Word: [ 笑了笑 ] not in wvmodel! Use random embedding instead.
# Word: [ 没带 ] not in wvmodel! Use random embedding instead.
# Word: [ 家门口 ] not in wvmodel! Use random embedding instead.
# Word: [ 面试官 ] not in wvmodel! Use random embedding instead.
# Word: [ 两岁 ] not in wvmodel! Use random embedding instead.
# Word: [ 坏消息 ] not in wvmodel! Use random embedding instead.
# Word: [ 90 ] not in wvmodel! Use random embedding instead.
# Word: [ 你别 ] not in wvmodel! Use random embedding instead.
# Word: [ 几句 ] not in wvmodel! Use random embedding instead.
# Word: [ 长时间 ] not in wvmodel! Use random embedding instead.
# Word: [ 打了个 ] not in wvmodel! Use random embedding instead.
# Word: [ 话音刚落 ] not in wvmodel! Use random embedding instead.
# Word: [ 小鸟 ] not in wvmodel! Use random embedding instead.
# Word: [ 围着 ] not in wvmodel! Use random embedding instead.
# Word: [ 所有人 ] not in wvmodel! Use random embedding instead.
# Word: [ 出租车 ] not in wvmodel! Use random embedding instead.
# Word: [ 第三天 ] not in wvmodel! Use random embedding instead.
# Word: [ 怀里 ] not in wvmodel! Use random embedding instead.
# Word: [ 300 ] not in wvmodel! Use random embedding instead.
# Word: [ 见状 ] not in wvmodel! Use random embedding instead.
# Word: [ 老农 ] not in wvmodel! Use random embedding instead.
# Word: [ 怕老婆 ] not in wvmodel! Use random embedding instead.
# Word: [ 洗脸 ] not in wvmodel! Use random embedding instead.
# Word: [ 兔兔 ] not in wvmodel! Use random embedding instead.
# Word: [ 忍无可忍 ] not in wvmodel! Use random embedding instead.
# Word: [ 那女 ] not in wvmodel! Use random embedding instead.
# Word: [ 灵机一动 ] not in wvmodel! Use random embedding instead.
# Word: [ 爸爸妈妈 ] not in wvmodel! Use random embedding instead.
# Word: [ 某君 ] not in wvmodel! Use random embedding instead.
# Word: [ 大惊 ] not in wvmodel! Use random embedding instead.
# Word: [ 小胖 ] not in wvmodel! Use random embedding instead.
# Word: [ 舅妈 ] not in wvmodel! Use random embedding instead.
# Word: [ 吃完饭 ] not in wvmodel! Use random embedding instead.
# Word: [ 老大爷 ] not in wvmodel! Use random embedding instead.
# Word: [ 电影院 ] not in wvmodel! Use random embedding instead.
# Word: [ 小刚 ] not in wvmodel! Use random embedding instead.
# Word: [ 方便面 ] not in wvmodel! Use random embedding instead.
# Word: [ 扭头 ] not in wvmodel! Use random embedding instead.
# Word: [ 六个 ] not in wvmodel! Use random embedding instead.
# Word: [ 边上 ] not in wvmodel! Use random embedding instead.
# Word: [ 情人节 ] not in wvmodel! Use random embedding instead.
# Word: [ 怒道 ] not in wvmodel! Use random embedding instead.
# Word: [ 不要紧 ] not in wvmodel! Use random embedding instead.
# Word: [ 有时候 ] not in wvmodel! Use random embedding instead.
# Word: [ 红着脸 ] not in wvmodel! Use random embedding instead.
# Word: [ 进屋 ] not in wvmodel! Use random embedding instead.
# Word: [ 黑线 ] not in wvmodel! Use random embedding instead.
# Word: [ 生个 ] not in wvmodel! Use random embedding instead.
# Word: [ 他妈 ] not in wvmodel! Use random embedding instead.
# Word: [ 背着 ] not in wvmodel! Use random embedding instead.
# Word: [ 停下来 ] not in wvmodel! Use random embedding instead.
# Word: [ 很漂亮 ] not in wvmodel! Use random embedding instead.
# Word: [ 一个个 ] not in wvmodel! Use random embedding instead.
# Word: [ 人来 ] not in wvmodel! Use random embedding instead.
# Word: [ 闲聊 ] not in wvmodel! Use random embedding instead.
# Word: [ 买菜 ] not in wvmodel! Use random embedding instead.
# Word: [ 卖掉 ] not in wvmodel! Use random embedding instead.
# Word: [ 一点儿 ] not in wvmodel! Use random embedding instead.
# Word: [ 他爸 ] not in wvmodel! Use random embedding instead.
# Word: [ 火车站 ] not in wvmodel! Use random embedding instead.
# Word: [ 悟空 ] not in wvmodel! Use random embedding instead.
# Word: [ 电话号码 ] not in wvmodel! Use random embedding instead.
# Word: [ 图书馆 ] not in wvmodel! Use random embedding instead.
# Word: [ 只会 ] not in wvmodel! Use random embedding instead.
# Word: [ 某个 ] not in wvmodel! Use random embedding instead.
# Word: [ 普通话 ] not in wvmodel! Use random embedding instead.
# Word: [ 妹纸 ] not in wvmodel! Use random embedding instead.
# Word: [ 70 ] not in wvmodel! Use random embedding instead.
# Word: [ 中年 ] not in wvmodel! Use random embedding instead.
# Word: [ 小萝莉 ] not in wvmodel! Use random embedding instead.
# Word: [ 伯克 ] not in wvmodel! Use random embedding instead.
# Word: [ 万美元 ] not in wvmodel! Use random embedding instead.
# Word: [ 精神病院 ] not in wvmodel! Use random embedding instead.
# Word: [ 门上 ] not in wvmodel! Use random embedding instead.
# Word: [ 婚后 ] not in wvmodel! Use random embedding instead.
# Word: [ 多人 ] not in wvmodel! Use random embedding instead.
# Word: [ 很难 ] not in wvmodel! Use random embedding instead.
# Word: [ 外国人 ] not in wvmodel! Use random embedding instead.
# Word: [ 十个 ] not in wvmodel! Use random embedding instead.
# Word: [ 狗狗 ] not in wvmodel! Use random embedding instead.
# Word: [ 二货 ] not in wvmodel! Use random embedding instead.
# Word: [ 宝马 ] not in wvmodel! Use random embedding instead.
# Word: [ 吃饱 ] not in wvmodel! Use random embedding instead.
# Word: [ 鼠标 ] not in wvmodel! Use random embedding instead.
# Word: [ 应声 ] not in wvmodel! Use random embedding instead.
# Word: [ 集市 ] not in wvmodel! Use random embedding instead.
# Word: [ 这张 ] not in wvmodel! Use random embedding instead.
# Word: [ 身份证 ] not in wvmodel! Use random embedding instead.
# Word: [ 偷吃 ] not in wvmodel! Use random embedding instead.
# Word: [ 发短信 ] not in wvmodel! Use random embedding instead.
# Word: [ 县令 ] not in wvmodel! Use random embedding instead.
# Word: [ 书上 ] not in wvmodel! Use random embedding instead.
# Word: [ 坐车 ] not in wvmodel! Use random embedding instead.
# Word: [ 讨好 ] not in wvmodel! Use random embedding instead.
# Word: [ 两种 ] not in wvmodel! Use random embedding instead.
# Word: [ 锅里 ] not in wvmodel! Use random embedding instead.
# Word: [ 别提 ] not in wvmodel! Use random embedding instead.
# Word: [ 非常高兴 ] not in wvmodel! Use random embedding instead.
# Word: [ 两条 ] not in wvmodel! Use random embedding instead.
# Word: [ 一笔 ] not in wvmodel! Use random embedding instead.
# Word: [ 太贵 ] not in wvmodel! Use random embedding instead.
# Word: [ 东家 ] not in wvmodel! Use random embedding instead.
# Word: [ 管理员 ] not in wvmodel! Use random embedding instead.
# Word: [ 答到 ] not in wvmodel! Use random embedding instead.
# Word: [ 几只 ] not in wvmodel! Use random embedding instead.
# Word: [ 吉姆 ] not in wvmodel! Use random embedding instead.
# Word: [ 这事 ] not in wvmodel! Use random embedding instead.
# Word: [ 小芳 ] not in wvmodel! Use random embedding instead.
# Word: [ 脱口而出 ] not in wvmodel! Use random embedding instead.
# Word: [ 赶到 ] not in wvmodel! Use random embedding instead.
# Word: [ 别说 ] not in wvmodel! Use random embedding instead.
# Word: [ 闺蜜 ] not in wvmodel! Use random embedding instead.
# Word: [ 人问 ] not in wvmodel! Use random embedding instead.
# Word: [ 我该 ] not in wvmodel! Use random embedding instead.
# Word: [ 出去玩 ] not in wvmodel! Use random embedding instead.
# Word: [ 尼玛 ] not in wvmodel! Use random embedding instead.
# Word: [ 响起 ] not in wvmodel! Use random embedding instead.
# Word: [ 听课 ] not in wvmodel! Use random embedding instead.
# Word: [ 耳边 ] not in wvmodel! Use random embedding instead.
# Word: [ 自我介绍 ] not in wvmodel! Use random embedding instead.
# Word: [ 那有 ] not in wvmodel! Use random embedding instead.
# Word: [ 读书人 ] not in wvmodel! Use random embedding instead.
# Word: [ 讲故事 ] not in wvmodel! Use random embedding instead.
# Word: [ 开着 ] not in wvmodel! Use random embedding instead.
# Word: [ 这才 ] not in wvmodel! Use random embedding instead.
# Word: [ 对此 ] not in wvmodel! Use random embedding instead.
# Word: [ 抓饭 ] not in wvmodel! Use random embedding instead.
# Word: [ 大吃一惊 ] not in wvmodel! Use random embedding instead.
# Word: [ 杯酒 ] not in wvmodel! Use random embedding instead.
# Word: [ 一分钟 ] not in wvmodel! Use random embedding instead.
# Word: [ 一模一样 ] not in wvmodel! Use random embedding instead.
# Word: [ 老二 ] not in wvmodel! Use random embedding instead.
# Word: [ 气呼呼 ] not in wvmodel! Use random embedding instead.
# Word: [ 它会 ] not in wvmodel! Use random embedding instead.
# Word: [ 这块 ] not in wvmodel! Use random embedding instead.
# Word: [ 艾子 ] not in wvmodel! Use random embedding instead.
# Word: [ 进水 ] not in wvmodel! Use random embedding instead.
# Word: [ 兜里 ] not in wvmodel! Use random embedding instead.
# Word: [ 不得了 ] not in wvmodel! Use random embedding instead.
# Word: [ 法国人 ] not in wvmodel! Use random embedding instead.
# Word: [ 爬起来 ] not in wvmodel! Use random embedding instead.
# Word: [ 程序员 ] not in wvmodel! Use random embedding instead.
# Word: [ 从没 ] not in wvmodel! Use random embedding instead.
# Word: [ 比划 ] not in wvmodel! Use random embedding instead.
# Word: [ 讲完 ] not in wvmodel! Use random embedding instead.
# Word: [ 玩游戏 ] not in wvmodel! Use random embedding instead.
# Word: [ 地向 ] not in wvmodel! Use random embedding instead.
# Word: [ 吃晚饭 ] not in wvmodel! Use random embedding instead.
# Word: [ 一年级 ] not in wvmodel! Use random embedding instead.
# Word: [ 骑着 ] not in wvmodel! Use random embedding instead.
# Word: [ 三只 ] not in wvmodel! Use random embedding instead.
# Word: [ 一棵树 ] not in wvmodel! Use random embedding instead.
# Word: [ 买个 ] not in wvmodel! Use random embedding instead.
# Word: [ 佳佳 ] not in wvmodel! Use random embedding instead.
# Word: [ 拍了拍 ] not in wvmodel! Use random embedding instead.
# Word: [ 老头子 ] not in wvmodel! Use random embedding instead.
# Word: [ 空中小姐 ] not in wvmodel! Use random embedding instead.
# Word: [ 卫生巾 ] not in wvmodel! Use random embedding instead.
# Word: [ 老三 ] not in wvmodel! Use random embedding instead.
# Word: [ 多钱 ] not in wvmodel! Use random embedding instead.
# Word: [ 会儿 ] not in wvmodel! Use random embedding instead.
# Word: [ 惊叫 ] not in wvmodel! Use random embedding instead.
# Word: [ 一惊 ] not in wvmodel! Use random embedding instead.
# Word: [ 就行 ] not in wvmodel! Use random embedding instead.
# Word: [ 万元 ] not in wvmodel! Use random embedding instead.
# Word: [ 回事 ] not in wvmodel! Use random embedding instead.
# Word: [ 买来 ] not in wvmodel! Use random embedding instead.
# Word: [ 肯德基 ] not in wvmodel! Use random embedding instead.
# Word: [ 学妹 ] not in wvmodel! Use random embedding instead.
# Word: [ 半小时 ] not in wvmodel! Use random embedding instead.
# Word: [ 请来 ] not in wvmodel! Use random embedding instead.
# Word: [ 带你去 ] not in wvmodel! Use random embedding instead.
# Word: [ 一到 ] not in wvmodel! Use random embedding instead.
# Word: [ 打饭 ] not in wvmodel! Use random embedding instead.
# Word: [ 席间 ] not in wvmodel! Use random embedding instead.
# Word: [ 说错 ] not in wvmodel! Use random embedding instead.
# Word: [ 一则 ] not in wvmodel! Use random embedding instead.
# Word: [ 默默地 ] not in wvmodel! Use random embedding instead.
# Word: [ 轻轻地 ] not in wvmodel! Use random embedding instead.
# Word: [ 好极了 ] not in wvmodel! Use random embedding instead.
# Word: [ 总要 ] not in wvmodel! Use random embedding instead.
# Word: [ 比尔 ] not in wvmodel! Use random embedding instead.
# Word: [ 课上 ] not in wvmodel! Use random embedding instead.
# Word: [ 这么久 ] not in wvmodel! Use random embedding instead.
# Word: [ 围观 ] not in wvmodel! Use random embedding instead.
# Word: [ 成绩单 ] not in wvmodel! Use random embedding instead.
# Word: [ 不来 ] not in wvmodel! Use random embedding instead.
# Word: [ 饭后 ] not in wvmodel! Use random embedding instead.
# Word: [ 期末考试 ] not in wvmodel! Use random embedding instead.
# Word: [ 点名 ] not in wvmodel! Use random embedding instead.
# Word: [ 哈哈哈 ] not in wvmodel! Use random embedding instead.
# Word: [ 带回家 ] not in wvmodel! Use random embedding instead.
# Word: [ 不听话 ] not in wvmodel! Use random embedding instead.
# Word: [ 把门 ] not in wvmodel! Use random embedding instead.
# Word: [ 借钱 ] not in wvmodel! Use random embedding instead.
# Word: [ 拉着 ] not in wvmodel! Use random embedding instead.
# Word: [ 学长 ] not in wvmodel! Use random embedding instead.
# Word: [ 上个月 ] not in wvmodel! Use random embedding instead.
# Word: [ 没好气 ] not in wvmodel! Use random embedding instead.
# Word: [ 另一只 ] not in wvmodel! Use random embedding instead.
# Word: [ 下楼 ] not in wvmodel! Use random embedding instead.
# Word: [ 一处 ] not in wvmodel! Use random embedding instead.
# Word: [ 男同事 ] not in wvmodel! Use random embedding instead.
# Word: [ 买票 ] not in wvmodel! Use random embedding instead.
# Word: [ 及格 ] not in wvmodel! Use random embedding instead.
# Word: [ 放着 ] not in wvmodel! Use random embedding instead.
# Word: [ 数到 ] not in wvmodel! Use random embedding instead.
# Word: [ 到时候 ] not in wvmodel! Use random embedding instead.
# Word: [ 鼓起勇气 ] not in wvmodel! Use random embedding instead.
# Word: [ 无可奈何 ] not in wvmodel! Use random embedding instead.
# Word: [ 第一句 ] not in wvmodel! Use random embedding instead.
# Word: [ 当着 ] not in wvmodel! Use random embedding instead.
# Word: [ 床前 ] not in wvmodel! Use random embedding instead.
# Word: [ 无语 ] not in wvmodel! Use random embedding instead.
# Word: [ 语重心长 ] not in wvmodel! Use random embedding instead.
# Word: [ 两张 ] not in wvmodel! Use random embedding instead.
# Word: [ 数学课 ] not in wvmodel! Use random embedding instead.
# Word: [ 同一个 ] not in wvmodel! Use random embedding instead.
# Word: [ 马路上 ] not in wvmodel! Use random embedding instead.
# Word: [ 110 ] not in wvmodel! Use random embedding instead.
# Word: [ 24 ] not in wvmodel! Use random embedding instead.
# Word: [ 乡下人 ] not in wvmodel! Use random embedding instead.
# Word: [ 要死 ] not in wvmodel! Use random embedding instead.
# Word: [ 圣诞节 ] not in wvmodel! Use random embedding instead.
# Word: [ 不语 ] not in wvmodel! Use random embedding instead.
# Word: [ 打车 ] not in wvmodel! Use random embedding instead.
# Word: [ 小白兔 ] not in wvmodel! Use random embedding instead.
# Word: [ 那还用说 ] not in wvmodel! Use random embedding instead.
# Word: [ 问其 ] not in wvmodel! Use random embedding instead.
# Word: [ 小侄女 ] not in wvmodel! Use random embedding instead.
# Word: [ 老和尚 ] not in wvmodel! Use random embedding instead.
# Word: [ 搭讪 ] not in wvmodel! Use random embedding instead.
# Word: [ 结账 ] not in wvmodel! Use random embedding instead.
# Word: [ 120 ] not in wvmodel! Use random embedding instead.
# Word: [ 说起 ] not in wvmodel! Use random embedding instead.
# Word: [ 换成 ] not in wvmodel! Use random embedding instead.
# Word: [ 王先生 ] not in wvmodel! Use random embedding instead.
# Word: [ 微博 ] not in wvmodel! Use random embedding instead.
# Word: [ 出外 ] not in wvmodel! Use random embedding instead.
# Word: [ 掉下来 ] not in wvmodel! Use random embedding instead.
# Word: [ 没多久 ] not in wvmodel! Use random embedding instead.
# Word: [ 照着 ] not in wvmodel! Use random embedding instead.
# Word: [ 买下 ] not in wvmodel! Use random embedding instead.
# Word: [ 时侯 ] not in wvmodel! Use random embedding instead.
# Word: [ 发给 ] not in wvmodel! Use random embedding instead.
# Word: [ 带上 ] not in wvmodel! Use random embedding instead.
# Word: [ 洗衣机 ] not in wvmodel! Use random embedding instead.
# Word: [ 传出 ] not in wvmodel! Use random embedding instead.
# Word: [ 大多数 ] not in wvmodel! Use random embedding instead.
# Word: [ 快来 ] not in wvmodel! Use random embedding instead.
# Word: [ 电视台 ] not in wvmodel! Use random embedding instead.
# Word: [ 怒气冲冲 ] not in wvmodel! Use random embedding instead.
# Word: [ 车门 ] not in wvmodel! Use random embedding instead.
# Word: [ 妞妞 ] not in wvmodel! Use random embedding instead.
# Word: [ 列车员 ] not in wvmodel! Use random embedding instead.
# Word: [ 店老板 ] not in wvmodel! Use random embedding instead.
# Word: [ 满头大汗 ] not in wvmodel! Use random embedding instead.
# Word: [ 接下来 ] not in wvmodel! Use random embedding instead.
# Word: [ 35 ] not in wvmodel! Use random embedding instead.
# Word: [ 七岁 ] not in wvmodel! Use random embedding instead.
# Word: [ 意味着 ] not in wvmodel! Use random embedding instead.
# Word: [ 取笑 ] not in wvmodel! Use random embedding instead.
# Word: [ 当兵 ] not in wvmodel! Use random embedding instead.
# Word: [ 转过身 ] not in wvmodel! Use random embedding instead.
# Word: [ 英语老师 ] not in wvmodel! Use random embedding instead.
# Word: [ 学姐 ] not in wvmodel! Use random embedding instead.
# Word: [ 13 ] not in wvmodel! Use random embedding instead.
# Word: [ 运动员 ] not in wvmodel! Use random embedding instead.
# Word: [ 死后 ] not in wvmodel! Use random embedding instead.
# Word: [ 不高兴地 ] not in wvmodel! Use random embedding instead.
# Word: [ 戴眼镜 ] not in wvmodel! Use random embedding instead.
# Word: [ 年青人 ] not in wvmodel! Use random embedding instead.
# Word: [ 般的 ] not in wvmodel! Use random embedding instead.
# Word: [ 地站 ] not in wvmodel! Use random embedding instead.
# Word: [ 历史课 ] not in wvmodel! Use random embedding instead.
# Word: [ 很淡 ] not in wvmodel! Use random embedding instead.
# Word: [ 女仆 ] not in wvmodel! Use random embedding instead.
# Word: [ 人多 ] not in wvmodel! Use random embedding instead.
# Word: [ 肚子饿 ] not in wvmodel! Use random embedding instead.
# Word: [ 降落伞 ] not in wvmodel! Use random embedding instead.
# Word: [ 气喘吁吁 ] not in wvmodel! Use random embedding instead.
# Word: [ 上楼 ] not in wvmodel! Use random embedding instead.
# Word: [ 问小明 ] not in wvmodel! Use random embedding instead.
# Word: [ 次日 ] not in wvmodel! Use random embedding instead.
# Word: [ 姥爷 ] not in wvmodel! Use random embedding instead.
# Word: [ 地走了 ] not in wvmodel! Use random embedding instead.
# Word: [ 我错 ] not in wvmodel! Use random embedding instead.
# Word: [ 贴着 ] not in wvmodel! Use random embedding instead.
# Word: [ 冷冷地 ] not in wvmodel! Use random embedding instead.
# Word: [ 出纳 ] not in wvmodel! Use random embedding instead.
# Word: [ 理发店 ] not in wvmodel! Use random embedding instead.
# Word: [ 一帮 ] not in wvmodel! Use random embedding instead.
# Word: [ 某女 ] not in wvmodel! Use random embedding instead.
# Word: [ 领着 ] not in wvmodel! Use random embedding instead.
# Word: [ 长发 ] not in wvmodel! Use random embedding instead.
# Word: [ 百万富翁 ] not in wvmodel! Use random embedding instead.
# Word: [ 我生 ] not in wvmodel! Use random embedding instead.
# Word: [ 五块 ] not in wvmodel! Use random embedding instead.
# Word: [ 取名 ] not in wvmodel! Use random embedding instead.
# Word: [ 好好学习 ] not in wvmodel! Use random embedding instead.
# Word: [ 北极熊 ] not in wvmodel! Use random embedding instead.
# Word: [ 好办 ] not in wvmodel! Use random embedding instead.
# Word: [ 铜钱 ] not in wvmodel! Use random embedding instead.
# Word: [ 每天晚上 ] not in wvmodel! Use random embedding instead.
# Word: [ 没想 ] not in wvmodel! Use random embedding instead.
# Word: [ 安眠药 ] not in wvmodel! Use random embedding instead.
# Word: [ 两瓶 ] not in wvmodel! Use random embedding instead.
# Word: [ 女老师 ] not in wvmodel! Use random embedding instead.
# Word: [ 惊呼 ] not in wvmodel! Use random embedding instead.
# Word: [ 14 ] not in wvmodel! Use random embedding instead.
# Word: [ 奥特曼 ] not in wvmodel! Use random embedding instead.
# Word: [ 手指头 ] not in wvmodel! Use random embedding instead.
# Word: [ 不卖 ] not in wvmodel! Use random embedding instead.
# Word: [ 拖拉机 ] not in wvmodel! Use random embedding instead.
# Word: [ 责问 ] not in wvmodel! Use random embedding instead.
# Word: [ 师兄 ] not in wvmodel! Use random embedding instead.
# Word: [ 桔子 ] not in wvmodel! Use random embedding instead.
# Word: [ 买不起 ] not in wvmodel! Use random embedding instead.
# Word: [ 热恋 ] not in wvmodel! Use random embedding instead.
# Word: [ 多好 ] not in wvmodel! Use random embedding instead.
# Word: [ 别忘了 ] not in wvmodel! Use random embedding instead.
# Word: [ 没来 ] not in wvmodel! Use random embedding instead.
# Word: [ 听听 ] not in wvmodel! Use random embedding instead.
# Word: [ 迈克 ] not in wvmodel! Use random embedding instead.
# Word: [ 提着 ] not in wvmodel! Use random embedding instead.
# Word: [ 一盆 ] not in wvmodel! Use random embedding instead.
# Word: [ 两句 ] not in wvmodel! Use random embedding instead.
# Word: [ 张嘴 ] not in wvmodel! Use random embedding instead.
# Word: [ 2000 ] not in wvmodel! Use random embedding instead.
# Word: [ 披萨 ] not in wvmodel! Use random embedding instead.
# Word: [ 归来 ] not in wvmodel! Use random embedding instead.
# Word: [ 阿花 ] not in wvmodel! Use random embedding instead.
# Word: [ 谈谈 ] not in wvmodel! Use random embedding instead.
# Word: [ 一百元 ] not in wvmodel! Use random embedding instead.
# Word: [ 太小 ] not in wvmodel! Use random embedding instead.
# Word: [ 不买 ] not in wvmodel! Use random embedding instead.
# Word: [ 我见 ] not in wvmodel! Use random embedding instead.
# Word: [ 侄儿 ] not in wvmodel! Use random embedding instead.
# Word: [ 巴扎 ] not in wvmodel! Use random embedding instead.
# Word: [ 脱下来 ] not in wvmodel! Use random embedding instead.
# Word: [ 我点 ] not in wvmodel! Use random embedding instead.
# Word: [ 秃顶 ] not in wvmodel! Use random embedding instead.
# Word: [ 俱乐部 ] not in wvmodel! Use random embedding instead.
# Word: [ 这名 ] not in wvmodel! Use random embedding instead.
# Word: [ 精神病人 ] not in wvmodel! Use random embedding instead.
# Word: [ 惊呆 ] not in wvmodel! Use random embedding instead.
# Word: [ 尝尝 ] not in wvmodel! Use random embedding instead.
# Word: [ 说实话 ] not in wvmodel! Use random embedding instead.
# Word: [ 许久 ] not in wvmodel! Use random embedding instead.
# Word: [ 那年 ] not in wvmodel! Use random embedding instead.
# Word: [ 买不到 ] not in wvmodel! Use random embedding instead.
# Word: [ 都行 ] not in wvmodel! Use random embedding instead.
# Word: [ 26 ] not in wvmodel! Use random embedding instead.
# Word: [ 考上 ] not in wvmodel! Use random embedding instead.
# Word: [ 打着 ] not in wvmodel! Use random embedding instead.
# Word: [ 23 ] not in wvmodel! Use random embedding instead.
# Word: [ 习惯性 ] not in wvmodel! Use random embedding instead.
# Word: [ 相见 ] not in wvmodel! Use random embedding instead.
# Word: [ 上铺 ] not in wvmodel! Use random embedding instead.
# Word: [ 好几个 ] not in wvmodel! Use random embedding instead.
# Word: [ 去过 ] not in wvmodel! Use random embedding instead.
# Word: [ 照镜子 ] not in wvmodel! Use random embedding instead.
# Word: [ 纪晓岚 ] not in wvmodel! Use random embedding instead.
# Word: [ 聊着 ] not in wvmodel! Use random embedding instead.
# Word: [ 弱弱 ] not in wvmodel! Use random embedding instead.
# Word: [ 微微一笑 ] not in wvmodel! Use random embedding instead.
# Word: [ 其人 ] not in wvmodel! Use random embedding instead.
# Word: [ 毛钱 ] not in wvmodel! Use random embedding instead.
# Word: [ 心理医生 ] not in wvmodel! Use random embedding instead.
# Word: [ 出头 ] not in wvmodel! Use random embedding instead.
# Word: [ 屁颠 ] not in wvmodel! Use random embedding instead.
# Word: [ 16 ] not in wvmodel! Use random embedding instead.
# Word: [ 这一 ] not in wvmodel! Use random embedding instead.
# Word: [ 邻座 ] not in wvmodel! Use random embedding instead.
# Word: [ 女士们 ] not in wvmodel! Use random embedding instead.
# Word: [ 急得 ] not in wvmodel! Use random embedding instead.
# Word: [ 告诉您 ] not in wvmodel! Use random embedding instead.
# Word: [ 胸前 ] not in wvmodel! Use random embedding instead.
# Word: [ 喝咖啡 ] not in wvmodel! Use random embedding instead.
# Word: [ 掏钱 ] not in wvmodel! Use random embedding instead.
# Word: [ 一车 ] not in wvmodel! Use random embedding instead.
# Word: [ 泡面 ] not in wvmodel! Use random embedding instead.
# Word: [ 经纪人 ] not in wvmodel! Use random embedding instead.
# Word: [ 写信给 ] not in wvmodel! Use random embedding instead.
# Word: [ 何用 ] not in wvmodel! Use random embedding instead.
# Word: [ 买家 ] not in wvmodel! Use random embedding instead.
# Word: [ 17 ] not in wvmodel! Use random embedding instead.
# Word: [ 地望 ] not in wvmodel! Use random embedding instead.
# Word: [ 人民币 ] not in wvmodel! Use random embedding instead.
# Word: [ 考试成绩 ] not in wvmodel! Use random embedding instead.
# Word: [ 这辈子 ] not in wvmodel! Use random embedding instead.
# Word: [ 花园里 ] not in wvmodel! Use random embedding instead.
# Word: [ 扔进 ] not in wvmodel! Use random embedding instead.
# Word: [ 家里人 ] not in wvmodel! Use random embedding instead.
# Word: [ 被窝 ] not in wvmodel! Use random embedding instead.
# Word: [ 推醒 ] not in wvmodel! Use random embedding instead.
# Word: [ 没钱 ] not in wvmodel! Use random embedding instead.
# Word: [ 当晚 ] not in wvmodel! Use random embedding instead.
# Word: [ 几口 ] not in wvmodel! Use random embedding instead.
# Word: [ 快给我 ] not in wvmodel! Use random embedding instead.
# Word: [ 发来 ] not in wvmodel! Use random embedding instead.
# Word: [ 新买 ] not in wvmodel! Use random embedding instead.
# Word: [ 城里人 ] not in wvmodel! Use random embedding instead.
# Word: [ 改为 ] not in wvmodel! Use random embedding instead.
# Word: [ 褡裢 ] not in wvmodel! Use random embedding instead.
# Word: [ 时说 ] not in wvmodel! Use random embedding instead.
# Word: [ 不怎么 ] not in wvmodel! Use random embedding instead.
# Word: [ 母猪 ] not in wvmodel! Use random embedding instead.
# Word: [ 听罢 ] not in wvmodel! Use random embedding instead.
# Word: [ 满面 ] not in wvmodel! Use random embedding instead.
# Word: [ 走后 ] not in wvmodel! Use random embedding instead.
# Word: [ 很长 ] not in wvmodel! Use random embedding instead.
# Word: [ 问起 ] not in wvmodel! Use random embedding instead.
# Word: [ 刹车 ] not in wvmodel! Use random embedding instead.
# Word: [ 一个男孩 ] not in wvmodel! Use random embedding instead.
# Word: [ 肚子疼 ] not in wvmodel! Use random embedding instead.
# Word: [ 看后 ] not in wvmodel! Use random embedding instead.
# Word: [ 怎样才能 ] not in wvmodel! Use random embedding instead.
# Word: [ 自已 ] not in wvmodel! Use random embedding instead.
# Word: [ 朱哈 ] not in wvmodel! Use random embedding instead.
# Word: [ 摄像头 ] not in wvmodel! Use random embedding instead.
# Word: [ 菜市场 ] not in wvmodel! Use random embedding instead.
# Word: [ 二十年 ] not in wvmodel! Use random embedding instead.
# Word: [ 闻到 ] not in wvmodel! Use random embedding instead.
# Word: [ 扬长而去 ] not in wvmodel! Use random embedding instead.
# Word: [ 有钱人 ] not in wvmodel! Use random embedding instead.
# Word: [ 车主 ] not in wvmodel! Use random embedding instead.
# Word: [ 地想 ] not in wvmodel! Use random embedding instead.
# Word: [ 封信 ] not in wvmodel! Use random embedding instead.
# Word: [ 两块 ] not in wvmodel! Use random embedding instead.
# Word: [ 两眼 ] not in wvmodel! Use random embedding instead.
# Word: [ 老妇人 ] not in wvmodel! Use random embedding instead.
# Word: [ 看门 ] not in wvmodel! Use random embedding instead.
# Word: [ 摊主 ] not in wvmodel! Use random embedding instead.
# Word: [ 雷人 ] not in wvmodel! Use random embedding instead.
# Word: [ 卖家 ] not in wvmodel! Use random embedding instead.
# Word: [ 美美 ] not in wvmodel! Use random embedding instead.
# Word: [ 自习 ] not in wvmodel! Use random embedding instead.
# Word: [ 该生 ] not in wvmodel! Use random embedding instead.
# Word: [ 结了婚 ] not in wvmodel! Use random embedding instead.
# Word: [ 化妆品 ] not in wvmodel! Use random embedding instead.
# Word: [ 总有 ] not in wvmodel! Use random embedding instead.
# Word: [ 我长 ] not in wvmodel! Use random embedding instead.
# Word: [ 三年级 ] not in wvmodel! Use random embedding instead.
# Word: [ 回头一看 ] not in wvmodel! Use random embedding instead.
# Word: [ 一整天 ] not in wvmodel! Use random embedding instead.
# Word: [ 鸡腿 ] not in wvmodel! Use random embedding instead.
# Word: [ 闭嘴 ] not in wvmodel! Use random embedding instead.
# Word: [ 清华 ] not in wvmodel! Use random embedding instead.
# Word: [ 小妹妹 ] not in wvmodel! Use random embedding instead.
# Word: [ 本事 ] not in wvmodel! Use random embedding instead.
# Word: [ 打开门 ] not in wvmodel! Use random embedding instead.
# Word: [ 她家 ] not in wvmodel! Use random embedding instead.
# Word: [ 小名 ] not in wvmodel! Use random embedding instead.
# Word: [ 屌丝 ] not in wvmodel! Use random embedding instead.
# Word: [ 小宝 ] not in wvmodel! Use random embedding instead.
# Word: [ 打呼噜 ] not in wvmodel! Use random embedding instead.
# Word: [ 很差 ] not in wvmodel! Use random embedding instead.
# Word: [ 愤愤 ] not in wvmodel! Use random embedding instead.
# Word: [ 数数 ] not in wvmodel! Use random embedding instead.
# Word: [ 放过 ] not in wvmodel! Use random embedding instead.
# Word: [ 眼里 ] not in wvmodel! Use random embedding instead.
# Word: [ 早恋 ] not in wvmodel! Use random embedding instead.
# Word: [ 满满 ] not in wvmodel! Use random embedding instead.
# Word: [ 谈起 ] not in wvmodel! Use random embedding instead.
# Word: [ 一米 ] not in wvmodel! Use random embedding instead.
# Word: [ 地笑 ] not in wvmodel! Use random embedding instead.
# Word: [ 冰棍 ] not in wvmodel! Use random embedding instead.
# Word: [ 更糟 ] not in wvmodel! Use random embedding instead.
# Word: [ 不爱 ] not in wvmodel! Use random embedding instead.
# Word: [ 妈呀 ] not in wvmodel! Use random embedding instead.
# Word: [ 忘带 ] not in wvmodel! Use random embedding instead.
# Word: [ 一户 ] not in wvmodel! Use random embedding instead.
# Word: [ 来电 ] not in wvmodel! Use random embedding instead.
# Word: [ 说些 ] not in wvmodel! Use random embedding instead.
# Word: [ 装进 ] not in wvmodel! Use random embedding instead.
# Word: [ 紧接着 ] not in wvmodel! Use random embedding instead.
# Word: [ 九个 ] not in wvmodel! Use random embedding instead.
# Word: [ 恶狠狠 ] not in wvmodel! Use random embedding instead.
# Word: [ 皮袄 ] not in wvmodel! Use random embedding instead.
# Word: [ 祖传 ] not in wvmodel! Use random embedding instead.
# Word: [ 生物课 ] not in wvmodel! Use random embedding instead.
# Word: [ 做作业 ] not in wvmodel! Use random embedding instead.
# Word: [ 府上 ] not in wvmodel! Use random embedding instead.
# Word: [ 3000 ] not in wvmodel! Use random embedding instead.
# Word: [ 长工 ] not in wvmodel! Use random embedding instead.
# Word: [ 院里 ] not in wvmodel! Use random embedding instead.
# Word: [ 亲嘴 ] not in wvmodel! Use random embedding instead.
# Word: [ 大婶 ] not in wvmodel! Use random embedding instead.
# Word: [ 里屋 ] not in wvmodel! Use random embedding instead.
# Word: [ 床头 ] not in wvmodel! Use random embedding instead.
# Word: [ 往回 ] not in wvmodel! Use random embedding instead.
# Word: [ 来时 ] not in wvmodel! Use random embedding instead.
# Word: [ 方向盘 ] not in wvmodel! Use random embedding instead.
# Word: [ 近视眼 ] not in wvmodel! Use random embedding instead.
# Word: [ 我答 ] not in wvmodel! Use random embedding instead.
# Word: [ 少妇 ] not in wvmodel! Use random embedding instead.
# Word: [ 第一名 ] not in wvmodel! Use random embedding instead.
# Word: [ 展昭 ] not in wvmodel! Use random embedding instead.
# Word: [ 小老婆 ] not in wvmodel! Use random embedding instead.
# Word: [ 会上 ] not in wvmodel! Use random embedding instead.
# Word: [ 掌柜的 ] not in wvmodel! Use random embedding instead.
# Word: [ 依麻目 ] not in wvmodel! Use random embedding instead.
# Word: [ 慢点 ] not in wvmodel! Use random embedding instead.
# Word: [ 百户 ] not in wvmodel! Use random embedding instead.
# Word: [ 邻家 ] not in wvmodel! Use random embedding instead.
# Word: [ 大学毕业 ] not in wvmodel! Use random embedding instead.
# Word: [ 付给 ] not in wvmodel! Use random embedding instead.
# Word: [ 找不着 ] not in wvmodel! Use random embedding instead.
# Word: [ 大树 ] not in wvmodel! Use random embedding instead.
# Word: [ 一阵子 ] not in wvmodel! Use random embedding instead.
# Word: [ 高高兴兴 ] not in wvmodel! Use random embedding instead.
# Word: [ 逛商场 ] not in wvmodel! Use random embedding instead.
# Word: [ 吓死 ] not in wvmodel! Use random embedding instead.
# Word: [ 墙角 ] not in wvmodel! Use random embedding instead.
# Word: [ 小亮 ] not in wvmodel! Use random embedding instead.
# Word: [ 一气之下 ] not in wvmodel! Use random embedding instead.
# Word: [ 喝一杯 ] not in wvmodel! Use random embedding instead.
# Word: [ 总爱 ] not in wvmodel! Use random embedding instead.
# Word: [ 年间 ] not in wvmodel! Use random embedding instead.
# Word: [ 念道 ] not in wvmodel! Use random embedding instead.
# Word: [ 出声 ] not in wvmodel! Use random embedding instead.
# Word: [ 某大学 ] not in wvmodel! Use random embedding instead.
# Word: [ 晚自习 ] not in wvmodel! Use random embedding instead.
# Word: [ 右脚 ] not in wvmodel! Use random embedding instead.
# Word: [ 作业本 ] not in wvmodel! Use random embedding instead.
# Word: [ 玲玲 ] not in wvmodel! Use random embedding instead.
# Word: [ 顺口 ] not in wvmodel! Use random embedding instead.
# Word: [ 小宝宝 ] not in wvmodel! Use random embedding instead.
# Word: [ 这年头 ] not in wvmodel! Use random embedding instead.
# Word: [ 离家出走 ] not in wvmodel! Use random embedding instead.
# Word: [ 刚上 ] not in wvmodel! Use random embedding instead.
# Word: [ 洗脚 ] not in wvmodel! Use random embedding instead.
# Word: [ 75 ] not in wvmodel! Use random embedding instead.
# Word: [ 气冲冲 ] not in wvmodel! Use random embedding instead.
# Word: [ 感谢上帝 ] not in wvmodel! Use random embedding instead.
# Word: [ 师母 ] not in wvmodel! Use random embedding instead.
# Word: [ 其妻 ] not in wvmodel! Use random embedding instead.
# Word: [ 算命先生 ] not in wvmodel! Use random embedding instead.
# Word: [ 乘务员 ] not in wvmodel! Use random embedding instead.
# Word: [ 捂着 ] not in wvmodel! Use random embedding instead.
# Word: [ 聪明人 ] not in wvmodel! Use random embedding instead.
# Word: [ 留着 ] not in wvmodel! Use random embedding instead.
# Word: [ 一言不发 ] not in wvmodel! Use random embedding instead.
# Word: [ 不远 ] not in wvmodel! Use random embedding instead.
# Word: [ 话费 ] not in wvmodel! Use random embedding instead.
# ...
# Word: [ 俩位 ] not in wvmodel! Use random embedding instead.
# Word: [ 宦之家 ] not in wvmodel! Use random embedding instead.
# Word: [ 食不下咽 ] not in wvmodel! Use random embedding instead.
# Word: [ 厌食症 ] not in wvmodel! Use random embedding instead.
# Word: [ 单反 ] not in wvmodel! Use random embedding instead.
# Word: [ 大波浪 ] not in wvmodel! Use random embedding instead.
# Word: [ 解解馋 ] not in wvmodel! Use random embedding instead.
# Word: [ 啃上 ] not in wvmodel! Use random embedding instead.
# Word: [ 好几顿 ] not in wvmodel! Use random embedding instead.
# Word: [ 水里试 ] not in wvmodel! Use random embedding instead.
# Word: [ 久婚 ] not in wvmodel! Use random embedding instead.
# Word: [ 无中生有 ] not in wvmodel! Use random embedding instead.
# Word: [ 后桌 ] not in wvmodel! Use random embedding instead.
# Word: [ 复习资料 ] not in wvmodel! Use random embedding instead.
# Word: [ 没考上 ] not in wvmodel! Use random embedding instead.
# Word: [ 真题 ] not in wvmodel! Use random embedding instead.
# Word: [ mp4 ] not in wvmodel! Use random embedding instead.
# Word: [ 危笃 ] not in wvmodel! Use random embedding instead.
# Word: [ 带猫 ] not in wvmodel! Use random embedding instead.
# Word: [ 师妹 ] not in wvmodel! Use random embedding instead.
# Word: [ 焦耳定律 ] not in wvmodel! Use random embedding instead.
# Word: [ 转化成 ] not in wvmodel! Use random embedding instead.
# Word: [ 地西 ] not in wvmodel! Use random embedding instead.
# Word: [ 荣吼 ] not in wvmodel! Use random embedding instead.
# Word: [ 撒朗 ] not in wvmodel! Use random embedding instead.
# Word: [ 俄罗斯语 ] not in wvmodel! Use random embedding instead.
# Word: [ 鸭鸡 ] not in wvmodel! Use random embedding instead.
# Word: [ 萨哈 ] not in wvmodel! Use random embedding instead.
# Word: [ 穿身 ] not in wvmodel! Use random embedding instead.
# Word: [ 人藏 ] not in wvmodel! Use random embedding instead.
# Word: [ 戏演 ] not in wvmodel! Use random embedding instead.
# Word: [ 白费力气 ] not in wvmodel! Use random embedding instead.
# Word: [ 人牌 ] not in wvmodel! Use random embedding instead.
# Word: [ 同花顺 ] not in wvmodel! Use random embedding instead.
# Word: [ 苏州人 ] not in wvmodel! Use random embedding instead.
# Word: [ 做马 ] not in wvmodel! Use random embedding instead.
# Word: [ 战无 ] not in wvmodel! Use random embedding instead.
# Word: [ 一败涂地 ] not in wvmodel! Use random embedding instead.
# Word: [ 连马 ] not in wvmodel! Use random embedding instead.
# Word: [ 揭奖 ] not in wvmodel! Use random embedding instead.
# Word: [ 浪用 ] not in wvmodel! Use random embedding instead.
# Word: [ 日坐愁城 ] not in wvmodel! Use random embedding instead.
# Word: [ 侯想 ] not in wvmodel! Use random embedding instead.
# Word: [ 车场 ] not in wvmodel! Use random embedding instead.
# Word: [ 交存 ] not in wvmodel! Use random embedding instead.
# Word: [ 川字 ] not in wvmodel! Use random embedding instead.
# Word: [ 川字来 ] not in wvmodel! Use random embedding instead.
# Word: [ 高额 ] not in wvmodel! Use random embedding instead.
# Word: [ 没钱付 ] not in wvmodel! Use random embedding instead.
# Word: [ 供款 ] not in wvmodel! Use random embedding instead.
# Word: [ 付下去 ] not in wvmodel! Use random embedding instead.
# Word: [ 原主 ] not in wvmodel! Use random embedding instead.
# Word: [ 很亏 ] not in wvmodel! Use random embedding instead.
# Word: [ 没太多 ] not in wvmodel! Use random embedding instead.
# Word: [ 平平淡淡 ] not in wvmodel! Use random embedding instead.
# Word: [ 检查官 ] not in wvmodel! Use random embedding instead.
# Word: [ 妈开 ] not in wvmodel! Use random embedding instead.
# Word: [ 前置 ] not in wvmodel! Use random embedding instead.
# Word: [ 远出 ] not in wvmodel! Use random embedding instead.
# Word: [ 后过 ] not in wvmodel! Use random embedding instead.
# Word: [ 埉 ] not in wvmodel! Use random embedding instead.
# Word: [ 大如 ] not in wvmodel! Use random embedding instead.
# Word: [ 昨在 ] not in wvmodel! Use random embedding instead.
# Word: [ 新河 ] not in wvmodel! Use random embedding instead.
# Word: [ 大如鹅 ] not in wvmodel! Use random embedding instead.
# Word: [ 甚不带 ] not in wvmodel! Use random embedding instead.
# Word: [ 夫笑 ] not in wvmodel! Use random embedding instead.
# Word: [ 疾驶 ] not in wvmodel! Use random embedding instead.
# Word: [ 避让 ] not in wvmodel! Use random embedding instead.
# Word: [ 骑者 ] not in wvmodel! Use random embedding instead.
# Word: [ 骑回去 ] not in wvmodel! Use random embedding instead.
# Word: [ 艾尔卡 ] not in wvmodel! Use random embedding instead.
# Word: [ 挥汗如雨 ] not in wvmodel! Use random embedding instead.
# Word: [ 我闻饭 ] not in wvmodel! Use random embedding instead.
# Word: [ 歹意 ] not in wvmodel! Use random embedding instead.
# Word: [ 发扫净 ] not in wvmodel! Use random embedding instead.
# Word: [ 钉好 ] not in wvmodel! Use random embedding instead.
# Word: [ 寻驴 ] not in wvmodel! Use random embedding instead.
# Word: [ 读着 ] not in wvmodel! Use random embedding instead.
# Word: [ 拔高 ] not in wvmodel! Use random embedding instead.
# Word: [ 拔苗助长 ] not in wvmodel! Use random embedding instead.
# Word: [ 四五年 ] not in wvmodel! Use random embedding instead.
# Word: [ 普通高中 ] not in wvmodel! Use random embedding instead.
# Word: [ 练练看 ] not in wvmodel! Use random embedding instead.
# Word: [ 就会空 ] not in wvmodel! Use random embedding instead.
# Word: [ 阴阳鱼 ] not in wvmodel! Use random embedding instead.
# Word: [ 常坑 ] not in wvmodel! Use random embedding instead.
# Word: [ 替罪羊 ] not in wvmodel! Use random embedding instead.
# Word: [ 当啷 ] not in wvmodel! Use random embedding instead.
# Word: [ 说药 ] not in wvmodel! Use random embedding instead.
# Word: [ 从过 ] not in wvmodel! Use random embedding instead.
# Word: [ 钻来 ] not in wvmodel! Use random embedding instead.
# Word: [ 掀翻 ] not in wvmodel! Use random embedding instead.
# Word: [ 人号 ] not in wvmodel! Use random embedding instead.
# Word: [ 碰过 ] not in wvmodel! Use random embedding instead.
# Word: [ 涂满 ] not in wvmodel! Use random embedding instead.
# Word: [ 鲍尔考 ] not in wvmodel! Use random embedding instead.
# Word: [ 一晌 ] not in wvmodel! Use random embedding instead.
# Word: [ 柿子树 ] not in wvmodel! Use random embedding instead.
# Word: [ 能头 ] not in wvmodel! Use random embedding instead.
# Word: [ 头朝下 ] not in wvmodel! Use random embedding instead.
# Word: [ 未损 ] not in wvmodel! Use random embedding instead.
# Word: [ 人较 ] not in wvmodel! Use random embedding instead.
# Word: [ 一挤 ] not in wvmodel! Use random embedding instead.
# Word: [ 业务部 ] not in wvmodel! Use random embedding instead.
# Word: [ 有餐 ] not in wvmodel! Use random embedding instead.
# Word: [ 柳橙汁 ] not in wvmodel! Use random embedding instead.
# Word: [ 倒转 ] not in wvmodel! Use random embedding instead.
# Word: [ 砖家 ] not in wvmodel! Use random embedding instead.
# Word: [ 烦心 ] not in wvmodel! Use random embedding instead.
# Word: [ 得妻 ] not in wvmodel! Use random embedding instead.
# Word: [ 夫复 ] not in wvmodel! Use random embedding instead.
# Word: [ 何求 ] not in wvmodel! Use random embedding instead.
# Word: [ 每片 ] not in wvmodel! Use random embedding instead.
# Word: [ 窟窿眼 ] not in wvmodel! Use random embedding instead.
# Word: [ 爸怒 ] not in wvmodel! Use random embedding instead.
# Word: [ 淌出 ] not in wvmodel! Use random embedding instead.
# Word: [ 热汤 ] not in wvmodel! Use random embedding instead.
# Word: [ 流了泪 ] not in wvmodel! Use random embedding instead.
# Word: [ 八五折 ] not in wvmodel! Use random embedding instead.
# Word: [ 妄想症 ] not in wvmodel! Use random embedding instead.
# Word: [ 出类拔萃 ] not in wvmodel! Use random embedding instead.
# Word: [ 会客厅 ] not in wvmodel! Use random embedding instead.
# Word: [ 画值 ] not in wvmodel! Use random embedding instead.
# Word: [ 栏写 ] not in wvmodel! Use random embedding instead.
# Word: [ 已齐 ] not in wvmodel! Use random embedding instead.
# Word: [ 地大吼 ] not in wvmodel! Use random embedding instead.
# Word: [ 2x3 ] not in wvmodel! Use random embedding instead.
# Word: [ 3x2 ] not in wvmodel! Use random embedding instead.
# Word: [ 朱二泉 ] not in wvmodel! Use random embedding instead.
# Word: [ 因撑 ] not in wvmodel! Use random embedding instead.
# Word: [ 木堆 ] not in wvmodel! Use random embedding instead.
# Word: [ 撑架 ] not in wvmodel! Use random embedding instead.
# Word: [ 客驳 ] not in wvmodel! Use random embedding instead.
# Word: [ 后客 ] not in wvmodel! Use random embedding instead.
# Word: [ 驳道 ] not in wvmodel! Use random embedding instead.
# Word: [ 城河 ] not in wvmodel! Use random embedding instead.
# Word: [ 拱石桥 ] not in wvmodel! Use random embedding instead.
# Word: [ 桥有 ] not in wvmodel! Use random embedding instead.
# Word: [ 桥洞 ] not in wvmodel! Use random embedding instead.
# Word: [ 用鼠 ] not in wvmodel! Use random embedding instead.
# Word: [ 那算个 ] not in wvmodel! Use random embedding instead.
# Word: [ 哗地 ] not in wvmodel! Use random embedding instead.
# Word: [ 脚蹬 ] not in wvmodel! Use random embedding instead.
# Word: [ 脚站 ] not in wvmodel! Use random embedding instead.
# Word: [ 时手 ] not in wvmodel! Use random embedding instead.
# Word: [ 人高马大 ] not in wvmodel! Use random embedding instead.
# Word: [ 排桌 ] not in wvmodel! Use random embedding instead.
# Word: [ 直嚷 ] not in wvmodel! Use random embedding instead.
# Word: [ 演场 ] not in wvmodel! Use random embedding instead.
# Word: [ 六十年 ] not in wvmodel! Use random embedding instead.
# Word: [ 我想求 ] not in wvmodel! Use random embedding instead.
# Word: [ 噘嘴 ] not in wvmodel! Use random embedding instead.
# Word: [ 径自 ] not in wvmodel! Use random embedding instead.
# Word: [ 越气 ] not in wvmodel! Use random embedding instead.
# Word: [ 我量 ] not in wvmodel! Use random embedding instead.
# Word: [ 整车 ] not in wvmodel! Use random embedding instead.
# Word: [ 不站 ] not in wvmodel! Use random embedding instead.
# Word: [ 煮化 ] not in wvmodel! Use random embedding instead.
# Word: [ 容声 ] not in wvmodel! Use random embedding instead.
# Word: [ 能修 ] not in wvmodel! Use random embedding instead.
# Word: [ 一没学过 ] not in wvmodel! Use random embedding instead.
# Word: [ 久后 ] not in wvmodel! Use random embedding instead.
# Word: [ 之计来 ] not in wvmodel! Use random embedding instead.
# Word: [ 水军 ] not in wvmodel! Use random embedding instead.
# Word: [ 施计 ] not in wvmodel! Use random embedding instead.
# Word: [ 轻摇 ] not in wvmodel! Use random embedding instead.
# Word: [ 公瑾 ] not in wvmodel! Use random embedding instead.
# Word: [ 我夜 ] not in wvmodel! Use random embedding instead.
# Word: [ 内必 ] not in wvmodel! Use random embedding instead.
# Word: [ 周瑜闻 ] not in wvmodel! Use random embedding instead.
# Word: [ 外交人员 ] not in wvmodel! Use random embedding instead.
# Word: [ 监测数据 ] not in wvmodel! Use random embedding instead.
# Word: [ 宋鑫学 ] not in wvmodel! Use random embedding instead.
# Word: [ 宋新 ] not in wvmodel! Use random embedding instead.
# Word: [ 人照 ] not in wvmodel! Use random embedding instead.
# Word: [ 添麻烦 ] not in wvmodel! Use random embedding instead.
# Word: [ 聪明起来 ] not in wvmodel! Use random embedding instead.
# Word: [ 宰客 ] not in wvmodel! Use random embedding instead.
# Word: [ 拉个 ] not in wvmodel! Use random embedding instead.
# Word: [ 兰州大学 ] not in wvmodel! Use random embedding instead.
# Word: [ 圈到 ] not in wvmodel! Use random embedding instead.
# Word: [ 表说 ] not in wvmodel! Use random embedding instead.
# Word: [ 七张 ] not in wvmodel! Use random embedding instead.
# Word: [ 88888 ] not in wvmodel! Use random embedding instead.
# Word: [ 边翻 ] not in wvmodel! Use random embedding instead.
# Word: [ 攒足 ] not in wvmodel! Use random embedding instead.
# Word: [ 懂情 ] not in wvmodel! Use random embedding instead.
# Word: [ 重义 ] not in wvmodel! Use random embedding instead.
# Word: [ 乐人 ] not in wvmodel! Use random embedding instead.
# Word: [ 吹起来 ] not in wvmodel! Use random embedding instead.
# Word: [ 你好坏 ] not in wvmodel! Use random embedding instead.
# Word: [ 无银地 ] not in wvmodel! Use random embedding instead.
# Word: [ 道兄 ] not in wvmodel! Use random embedding instead.
# Word: [ 滑盖 ] not in wvmodel! Use random embedding instead.
# Word: [ 涨势 ] not in wvmodel! Use random embedding instead.
# Word: [ 花季少女 ] not in wvmodel! Use random embedding instead.
# Word: [ 军大衣 ] not in wvmodel! Use random embedding instead.
# Word: [ 有演 ] not in wvmodel! Use random embedding instead.
# Word: [ 找戏 ] not in wvmodel! Use random embedding instead.
# Word: [ 荆钗 ] not in wvmodel! Use random embedding instead.
# Word: [ 蔡伯喈 ] not in wvmodel! Use random embedding instead.
# Word: [ 王十朋 ] not in wvmodel! Use random embedding instead.
# Word: [ 想照 ] not in wvmodel! Use random embedding instead.
# Word: [ 彩色照片 ] not in wvmodel! Use random embedding instead.
# Word: [ 除尘 ] not in wvmodel! Use random embedding instead.
# Word: [ 道恩问 ] not in wvmodel! Use random embedding instead.
# Word: [ 巴布 ] not in wvmodel! Use random embedding instead.
# Word: [ 要罚 ] not in wvmodel! Use random embedding instead.
# Word: [ 只罚 ] not in wvmodel! Use random embedding instead.
# Word: [ 重多 ] not in wvmodel! Use random embedding instead.
# Word: [ 几餐 ] not in wvmodel! Use random embedding instead.
# Word: [ 头个 ] not in wvmodel! Use random embedding instead.
# Word: [ 两餐 ] not in wvmodel! Use random embedding instead.
# Word: [ 老火 ] not in wvmodel! Use random embedding instead.
# Word: [ 瓶瓶罐罐 ] not in wvmodel! Use random embedding instead.
# Word: [ 手对 ] not in wvmodel! Use random embedding instead.
# Word: [ 凯美瑞 ] not in wvmodel! Use random embedding instead.
# Word: [ 从哥 ] not in wvmodel! Use random embedding instead.
# Word: [ 捷达 ] not in wvmodel! Use random embedding instead.
# Word: [ 寻短见 ] not in wvmodel! Use random embedding instead.
# Word: [ 义举 ] not in wvmodel! Use random embedding instead.
# Word: [ 赞赏不已 ] not in wvmodel! Use random embedding instead.
# Word: [ 岂知 ] not in wvmodel! Use random embedding instead.
# Word: [ 两留 ] not in wvmodel! Use random embedding instead.
# Word: [ 对小浩 ] not in wvmodel! Use random embedding instead.
# Word: [ 洛洛考 ] not in wvmodel! Use random embedding instead.
# Word: [ 多一点儿 ] not in wvmodel! Use random embedding instead.
# Word: [ 无势 ] not in wvmodel! Use random embedding instead.
# Word: [ 窗纸 ] not in wvmodel! Use random embedding instead.
# Word: [ 吟起 ] not in wvmodel! Use random embedding instead.
# Word: [ 诗来 ] not in wvmodel! Use random embedding instead.
# Word: [ 正昏 ] not in wvmodel! Use random embedding instead.
# Word: [ 寒门 ] not in wvmodel! Use random embedding instead.
# Word: [ 千卷 ] not in wvmodel! Use random embedding instead.
# Word: [ 钱串 ] not in wvmodel! Use random embedding instead.
# Word: [ 半根 ] not in wvmodel! Use random embedding instead.
# Word: [ 出户 ] not in wvmodel! Use random embedding instead.
# Word: [ 休惊 ] not in wvmodel! Use random embedding instead.
# Word: [ 黄尾犬 ] not in wvmodel! Use random embedding instead.
# Word: [ 莫碍 ] not in wvmodel! Use random embedding instead.
# Word: [ 墙砖 ] not in wvmodel! Use random embedding instead.
# Word: [ 黄狗直 ] not in wvmodel! Use random embedding instead.
# Word: [ 追住 ] not in wvmodel! Use random embedding instead.
# Word: [ 喝住 ] not in wvmodel! Use random embedding instead.
# Word: [ 黄狗 ] not in wvmodel! Use random embedding instead.
# Word: [ 重作 ] not in wvmodel! Use random embedding instead.
# Word: [ 例外情况 ] not in wvmodel! Use random embedding instead.
# Word: [ 那验 ] not in wvmodel! Use random embedding instead.
# Word: [ 走人 ] not in wvmodel! Use random embedding instead.
# Word: [ 风雪交加 ] not in wvmodel! Use random embedding instead.
# Word: [ 田字格 ] not in wvmodel! Use random embedding instead.
# Word: [ 文具盒 ] not in wvmodel! Use random embedding instead.
# Word: [ 药力 ] not in wvmodel! Use random embedding instead.
# Word: [ 上放个 ] not in wvmodel! Use random embedding instead.
# Word: [ 159 ] not in wvmodel! Use random embedding instead.
# Word: [ 气沉 ] not in wvmodel! Use random embedding instead.
# Word: [ 铿锵有力 ] not in wvmodel! Use random embedding instead.
# Word: [ 女年 ] not in wvmodel! Use random embedding instead.
# Word: [ 名女 ] not in wvmodel! Use random embedding instead.
# Word: [ 死牢 ] not in wvmodel! Use random embedding instead.
# Word: [ 很强 ] not in wvmodel! Use random embedding instead.
# Word: [ 求过 ] not in wvmodel! Use random embedding instead.
# Word: [ 天赐 ] not in wvmodel! Use random embedding instead.
# Word: [ 嘬 ] not in wvmodel! Use random embedding instead.
# Word: [ 双耳 ] not in wvmodel! Use random embedding instead.
# Word: [ 饿不死 ] not in wvmodel! Use random embedding instead.
# Word: [ 胡写 ] not in wvmodel! Use random embedding instead.
# 完成！
# Embedding matrix shape:
#  (50001, 300)

# %%
import keras
from keras.models import Sequential, Model
from keras.layers import Input, Dense, GRU, LSTM, Activation, Dropout, Embedding
from keras.layers import Multiply, Concatenate, Dot

from sklearn.metrics import f1_score

# lstm
wv_dim = 300
n_timesteps = maxlen
inputs = Input(shape=(maxlen,))
embedding_sequences = Embedding(vocab_size+1, wv_dim, input_length=maxlen, weights=[embedding_matrix])(inputs)
lstm = LSTM(128, return_sequences= False)(embedding_sequences)
l = Dense(128, activation="tanh")(lstm)
l = Dropout(0.5)(l)
l = Dense(3, activation="softmax")(l)
m = Model(inputs, l)
m.summary()
m.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
m.fit(X_train, y_train, epochs=10, batch_size=32, validation_split=0.2)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0901 18:15:39.146509 164324 deprecation_wrapper.py:119] From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0901 18:15:39.158504 164324 deprecation_wrapper.py:119] From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0901 18:15:39.161470 164324 deprecation_wrapper.py:119] From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0901 18:15:39.168451 164324 deprecation_wrapper.py:119] From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0901 18:15:39.169475 164324 deprecation_wrapper.py:119] From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0901 18:15:39.524498 164324 deprecation.py:506] From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0901 18:15:39.548433 164324 deprecation_wrapper.py:119] From D:\Anaconda3\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0901 18:15:39.574385 164324 deprecation.py:323] From D:\Anaconda3\lib\site-packages\tensorflow\python\ops\nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 70)                0
# _________________________________________________________________
# embedding_1 (Embedding)      (None, 70, 300)           15000300
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 128)               219648
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 15,236,847
# Trainable params: 15,236,847
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-7fd8dde8b7c3> in <module>
#      20
#      21 for i in range(32):
# ---> 22     m.fit(X_train, y_train, epochs=1, batch_size=32)
#      23     y_pred = m.predict(X_test, batch_size=32)
#      24     y_pred = np.argmax(y_pred, axis=1)
#
# D:\Anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# D:\Anaconda3\lib\site-packages\keras\engine\training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2695
#    2696     def __call__(self, inputs):
# -> 2697         if hasattr(get_session(), '_make_callable_from_options'):
#    2698             if py_any(is_sparse(x) for x in self.inputs):
#    2699                 if py_any(is_tensor(x) for x in inputs):
#
# D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in get_session()
#     204                     v._keras_initialized = True
#     205                 if uninitialized_vars:
# --> 206                     session.run(tf.variables_initializer(uninitialized_vars))
#     207     # hack for list_devices() function.
#     208     # list_devices() function is not available under tensorflow r1.3.
#
# D:\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     948     try:
#     949       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 950                          run_metadata_ptr)
#     951       if run_metadata:
#     952         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# D:\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1171     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1172       results = self._do_run(handle, final_targets, final_fetches,
# -> 1173                              feed_dict_tensor, options, run_metadata)
#    1174     else:
#    1175       results = []
#
# D:\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1348     if handle is None:
#    1349       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1350                            run_metadata)
#    1351     else:
#    1352       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# D:\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1354   def _do_call(self, fn, *args):
#    1355     try:
# -> 1356       return fn(*args)
#    1357     except errors.OpError as e:
#    1358       message = compat.as_text(e.message)
#
# D:\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1339       self._extend_graph()
#    1340       return self._call_tf_sessionrun(
# -> 1341           options, feed_dict, fetch_list, target_list, run_metadata)
#    1342
#    1343     def _prun_fn(handle, feed_dict, fetch_list):
#
# D:\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1427     return tf_session.TF_SessionRun_wrapper(
#    1428         self._session, options, feed_dict, fetch_list, target_list,
# -> 1429         run_metadata)
#    1430
#    1431   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
